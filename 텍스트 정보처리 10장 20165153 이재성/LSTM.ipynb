# %%
#import keras
#import tensorflow
#print(keras.__version__, tensorflow.__version__)

#!pip uninstall keras
#!pip install keras==2.3.1
#!pip install tensorflow==2.2.0

# %%
# !pip list
# Out:
# Package                            Version
# WARNING: You are using pip version 20.2.4; however, version 20.3 is available.
# You should consider upgrading via the 'c:\users\samsung\anaconda3\python.exe -m pip install --upgrade pip' command.
# ---------------------------------- -------------------
# absl-py                            0.11.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.12
# anaconda-project                   0.8.3
# argh                               0.26.2
# asn1crypto                         1.3.0
# astroid                            2.4.2
# astropy                            4.0.1.post1
# astunparse                         1.6.3
# atomicwrites                       1.4.0
# attrs                              19.3.0
# autopep8                           1.5.3
# awscli                             1.18.178
# Babel                              2.8.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.1.7
# beautifulsoup4                     4.9.1
# bitarray                           1.4.0
# bkcharts                           0.2
# bleach                             3.1.5
# bokeh                              2.1.1
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cachetools                         4.1.1
# certifi                            2020.6.20
# cffi                               1.14.0
# chardet                            3.0.4
# click                              7.1.2
# cloudpickle                        1.5.0
# clyent                             1.2.2
# colorama                           0.4.3
# comtypes                           1.1.7
# conda                              4.8.3
# conda-build                        3.18.11
# conda-package-handling             1.7.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cryptography                       2.9.2
# cycler                             0.10.0
# Cython                             0.29.14
# cytoolz                            0.10.1
# dask                               2.20.0
# decorator                          4.4.2
# defusedxml                         0.6.0
# diff-match-patch                   20200713
# distributed                        2.20.0
# docutils                           0.15.2
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# feedparser                         6.0.1
# filelock                           3.0.12
# flake8                             3.8.3
# Flask                              1.1.2
# fsspec                             0.7.4
# future                             0.18.2
# gast                               0.3.3
# gensim                             3.8.3
# gevent                             20.6.2
# glob2                              0.7
# gmpy2                              2.0.8
# google-auth                        1.23.0
# google-auth-oauthlib               0.4.2
# google-pasta                       0.2.0
# greenlet                           0.4.16
# grpcio                             1.33.2
# h5py                               2.10.0
# HeapDict                           1.0.1
# html5lib                           1.1
# idna                               2.10
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 1.7.0
# intervaltree                       3.0.2
# ipykernel                          5.3.2
# ipython                            7.16.1
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.1
# isort                              4.3.21
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.1
# Jinja2                             2.11.2
# joblib                             0.16.0
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.6
# jupyter-console                    6.1.0
# jupyter-core                       4.6.3
# jupyterlab                         2.1.5
# jupyterlab-server                  1.2.0
# Keras                              2.3.1
# Keras-Applications                 1.0.8
# Keras-Preprocessing                1.1.2
# keyring                            21.2.1
# kiwisolver                         1.2.0
# lazy-object-proxy                  1.4.3
# libarchive-c                       2.9
# llvmlite                           0.33.0+1.g022ab0f
# locket                             0.2.0
# lxml                               4.5.2
# Markdown                           3.3.3
# MarkupSafe                         1.1.1
# matplotlib                         3.2.2
# mccabe                             0.6.1
# menuinst                           1.4.16
# mistune                            0.8.4
# mkl-fft                            1.1.0
# mkl-random                         1.1.1
# mkl-service                        2.3.0
# mock                               4.0.2
# more-itertools                     8.4.0
# mpmath                             1.1.0
# msgpack                            1.0.0
# multipledispatch                   0.6.0
# navigator-updater                  0.2.1
# nbconvert                          5.6.1
# nbformat                           5.0.7
# networkx                           2.4
# nitk                               0.1
# nltk                               3.5
# nose                               1.3.7
# notebook                           6.0.3
# numba                              0.50.1
# numexpr                            2.7.1
# numpy                              1.18.5
# numpydoc                           1.1.0
# oauthlib                           3.1.0
# olefile                            0.46
# openpyxl                           3.0.4
# opt-einsum                         3.3.0
# packaging                          20.4
# pandas                             1.0.5
# pandocfilters                      1.4.2
# paramiko                           2.7.1
# parso                              0.7.0
# partd                              1.1.0
# path                               13.1.0
# pathlib2                           2.3.5
# pathtools                          0.1.2
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             7.2.0
# pip                                20.2.4
# pkginfo                            1.5.0.1
# pluggy                             0.13.1
# ply                                3.11
# prometheus-client                  0.8.0
# prompt-toolkit                     3.0.5
# protobuf                           3.14.0
# psutil                             5.7.0
# py                                 1.9.0
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.5
# pydocstyle                         5.0.2
# pyflakes                           2.2.0
# Pygments                           2.6.1
# pylint                             2.5.3
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          19.1.0
# pyparsing                          2.4.7
# PyPDF2                             1.26.0
# pyreadline                         2.1
# pyrsistent                         0.16.0
# PySocks                            1.7.1
# pytest                             5.4.3
# python-crfsuite                    0.9.7
# python-dateutil                    2.8.1
# python-docx                        0.8.10
# python-jsonrpc-server              0.3.4
# python-language-server             0.34.1
# pytz                               2020.1
# PyWavelets                         1.1.1
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.3.1
# pyzmq                              19.0.1
# QDarkStyle                         2.8.1
# QtAwesome                          0.7.2
# qtconsole                          4.7.5
# QtPy                               1.9.0
# queuelib                           1.5.0
# regex                              2020.6.8
# requests                           2.24.0
# requests-oauthlib                  1.3.0
# rope                               0.17.0
# rsa                                4.5
# Rtree                              0.9.4
# ruamel-yaml                        0.15.87
# scikit-image                       0.16.2
# scikit-learn                       0.23.1
# scipy                              1.4.1
# seaborn                            0.10.1
# Send2Trash                         1.5.0
# setuptools                         49.2.0.post20200714
# sgmllib3k                          1.0.0
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# sip                                4.19.13
# six                                1.15.0
# sklearn                            0.0
# smart-open                         3.0.0
# snowballstemmer                    2.0.0
# sortedcollections                  1.2.1
# sortedcontainers                   2.2.2
# soupsieve                          2.0.1
# Sphinx                             3.1.2
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.3
# spyder                             4.1.4
# spyder-kernels                     1.9.2
# SQLAlchemy                         1.3.18
# statsmodels                        0.11.1
# sympy                              1.6.1
# tables                             3.6.1
# tblib                              1.6.0
# tensorboard                        2.2.2
# tensorboard-plugin-wit             1.7.0
# tensorflow                         2.2.0
# tensorflow-estimator               2.2.0
# termcolor                          1.1.0
# terminado                          0.8.3
# testpath                           0.4.4
# threadpoolctl                      2.1.0
# toml                               0.10.1
# toolz                              0.10.0
# tornado                            6.0.4
# tqdm                               4.47.0
# traitlets                          4.3.3
# typing-extensions                  3.7.4.2
# ujson                              1.35
# unicodecsv                         0.14.1
# urllib3                            1.25.9
# uuid                               1.30
# watchdog                           0.10.3
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wheel                              0.34.2
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.11.2
# xlrd                               1.2.0
# XlsxWriter                         1.2.9
# xlwings                            0.19.5
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.30.0
# zict                               2.0.0
# zipp                               3.1.0
# zope.event                         4.4
# zope.interface                     4.7.1

# %%
from __future__ import print_function
import numpy as np
import random
import sys

# %%
path = "shakespeare_final.txt"
text = open(path).read().lower()

characters = sorted(list(set(text)))

print('corpus length:', len(text))
print('total chars:', len(characters))
# Out:
# corpus length: 581432
# total chars: 61

# %%
char2indices = dict((c, i) for i, c in enumerate(characters))
indices2char = dict((i, c) for i, c in enumerate(characters))

# %%
# 텍스트를 어느정도 불필요한 부분은 최대길이(maxlen) 문자로 일련의 문자열씩 자른다.

maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 193798

# %%
# 인덱스를 벡터화된 형태로 변환

X = np.zeros((len(sentences), maxlen, len(characters)), dtype=np.bool)
y = np.zeros((len(sentences), len(characters)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char2indices[char]] = 1
    y[i, char2indices[next_chars[i]]] = 1

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM,Activation,Dropout
from keras.optimizers import RMSprop

# %%
# 모델 구축
model = Sequential()

model.add(LSTM(128, input_shape=(maxlen, len(characters))))
model.add(Dense(len(characters)))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer=RMSprop(lr=0.01))

print (model.summary())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-64-073f16b915b7> in <module>
#       2 model = Sequential()
#       3
# ----> 4 model.add(LSTM(128, input_shape=(maxlen, len(characters))))
#       5 model.add(Dense(len(characters)))
#       6 model.add(Activation('softmax'))
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     try:
#     456       result = method(self, *args, **kwargs)
# --> 457     finally:
#     458       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#     459     return result
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py in add(self, layer)
#     204           raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#     205         self.outputs = [
# --> 206             nest.flatten(layer._inbound_nodes[-1].output_tensors)[0]
#     207         ]
#     208         self.inputs = layer_utils.get_source_inputs(self.outputs[0])
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\layers\recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     657     # tensors, then add them to the inputs and temporarily modify the
#     658     # input_spec to include them.
# --> 659
#     660     additional_inputs = []
#     661     additional_specs = []
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     923                     # Wrap Tensors in `outputs` in `tf.identity` to avoid
#     924                     # circular dependencies.
# --> 925                     outputs = base_layer_utils.mark_as_return(outputs, acd)
#     926                 else:
#     927                   outputs = call_fn(cast_inputs, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1115
#    1116   @property
# -> 1117   @doc_controls.do_not_doc_inheritable
#    1118   def updates(self):
#    1119     collected_updates = []
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\layers\recurrent_v2.py in call(self, inputs, mask, training, initial_state)
#    1181               **gpu_lstm_kwargs)
#    1182         else:
# -> 1183           last_output, outputs, new_h, new_c, runtime = standard_lstm(
#    1184               **normal_lstm_kwargs)
#    1185       else:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\layers\recurrent_v2.py in lstm_with_backend_selection(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths, zero_output_for_mask)
#    1555   # sees multiple LSTM layers added into same graph, and it will be able
#    1556   # to pair up the different implementations across them.
# -> 1557   api_name = 'lstm_' + str(uuid.uuid4())
#    1558   defun_standard_lstm = _generate_defun_backend(
#    1559       api_name, _CPU_DEVICE_NAME, standard_lstm)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2826   containing those operations. The callable produced by `defun` contains only
#    2827   the subgraph of TensorFlow operations that were executed when the Python
# -> 2828   function was called with a particular input signature, defined as a list
#    2829   of the shapes and dtypes of the Python function's Tensor-valued arguments and
#    2830   the values of its non-Tensor Python objects.
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3211             autograph=autograph,
#    3212             autograph_options=experimental_autograph_options,
# -> 3213             experimental_compile=experimental_compile,
#    3214             experimental_relax_shapes=experimental_relax_shapes))
#    3215
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3062     return output
#    3063   ```
# -> 3064
#    3065   For more information see `tf.autograph`.
#    3066
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __init__(self, func_graph, attrs, shared_func_graph, function_spec)
#    1492   """Callable object encapsulating a function definition and its gradient.
#    1493
# -> 1494   `ConcreteFunction` is a callable that encapsulates a function definition and
#    1495   is differentiable under `tf.GradientTape` objects.
#    1496   """
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in <listcomp>(.0)
#    1492   """Callable object encapsulating a function definition and its gradient.
#    1493
# -> 1494   `ConcreteFunction` is a callable that encapsulates a function definition and
#    1495   is differentiable under `tf.GradientTape` objects.
#    1496   """
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\lazy_loader.py in __getattr__(self, item)
#      60
#      61   def __getattr__(self, item):
# ---> 62     module = self._load()
#      63     return getattr(module, item)
#      64
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\lazy_loader.py in _load(self)
#      43     """Load the module and insert it into the parent's globals."""
#      44     # Import the target module and insert it into the parent's namespace
# ---> 45     module = importlib.import_module(self.__name__)
#      46     self._parent_module_globals[self._local_name] = module
#      47
#
# ~\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'tensorflow.python.ops.numpy_ops'
