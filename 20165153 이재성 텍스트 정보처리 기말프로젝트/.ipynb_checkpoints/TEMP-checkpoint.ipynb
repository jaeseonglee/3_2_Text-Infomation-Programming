# %% [markdown]
# # train, test 불러오기 - xlsx (엑셀)

# %%
import xlrd

workbook = xlrd.open_workbook("train_test.xlsx")

# train
worksheet = workbook.sheet_by_index(0) # train sheet에 접근합니다.
train = worksheet.col_values(3) # document_morpheme 열(3 번째 열)의 값들을 document_morpheme 변수에 저장합니다.
y_train = worksheet.col_values(2)

# test
worksheet = workbook.sheet_by_index(1) # test sheet에 접근합니다.
test = worksheet.col_values(3) # document_morpheme 열(3 번째 열)의 값들을 document_morpheme 변수에 저장합니다.
y_test = worksheet.col_values(2)

# %%
type(train)
# Out:
# list

# %% [markdown]
# # 정수 인코딩

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()

tokenizer.fit_on_texts(train)

# 벡터화
x_train = tokenizer.texts_to_sequences(train)
x_test = tokenizer.texts_to_sequences(test)

# %%
# 총 단어 수
total_word = len(tokenizer.word_index)

# 단어 집합의 크기
vocab_size = total_word+1

#
import numpy as np
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
import pickle

# 만들어진 tokenizer를 저장해줍니다. - 추 후에 받을 데이터를 정수 인코딩 해주기 위함.
with open('tokenizer.p', 'wb') as file: # 파일을 바이너리 쓰기 모드(wb)로 열기 
    pickle.dump(tokenizer, file) # 저장하기

# %%
import pandas as pd

# 데이터의 최대 길이 확인

# train + test 데이터 합치기
all_data = train + test

max_len = 0
for i in all_data:
    if max_len <= len(i):
        max_len = len(i)
        
print(max_len)
# Out:
# 264

# %%
# 패딩을 통해 길이를 맞춰줍니다.
# from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.sequence import pad_sequences

x_train = pad_sequences(x_train, maxlen = 100)
x_test = pad_sequences(x_test, maxlen = 80)

# %%
x_test.shape
# Out:
# (49572, 80)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape, max_len, vocab_size
# Out:
# ((148738, 100), (49572, 80), (148738,), (49572,), 264, 39682)

# %% [markdown]
# # 모델1 - 기본 dense layer

# %%
from tensorflow.keras.layers import Dense, Dropout, Embedding, LSTM
from tensorflow.keras.models import Sequential

# %% [markdown]
# ### 모델 구축

# %%
model__ = Sequential()

model__.add(Embedding(vocab_size, 128)) # 21일 주어진 데이터를 예측하기 위해, embedding 층을 처음에 넣어줘야 합니다.
model__.add(LSTM(64, activation='relu'))
model__.add(Dropout(0.5))
model__.add(Dense(32, activation='relu'))
model__.add(Dense(1, activation='sigmoid')) # output shape을 (None, 1)로 맞춰줍니다. - 추 후, 주어진 데이터을 이용하여 모델의 예측한 값을 뽑기위해...

model__.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model__.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 128)         5079296
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                49408
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 5,130,817
# Trainable params: 5,130,817
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습

# %%
model__.fit(x_train, y_train, epochs = 1, batch_size = 64, validation_split = 0.2)
# Out:
# 1860/1860 [==============================] - 239s 129ms/step - loss: 5271090176.0000 - accuracy: 0.8049 - val_loss: 0.3608 - val_accuracy: 0.8425

# %%
# loaded_model = load_model('best_model.h5')
print(model.evaluate(x_test, y_test))
# Out:
# 1550/1550 [==============================] - 25s 16ms/step - loss: 0.3998 - accuracy: 0.8399
# [0.3998051583766937, 0.8398894667625427]

# %% [markdown]
# ### 모델 저장 // 나중에 다시 load 해서 test 데이터로 바로 예측하기 위함.

# %%
model__.save("model.h5")

# %% [markdown]
# # 모델 로드 후, 주어진 데이터로 예측하기

# %% [markdown]
# ### 모델 로드

# %%
# from keras.models import load_model
from tensorflow.keras.models import load_model

# %%
model = load_model("model.h5")

# %% [markdown]
# ### 주어진 데이터 로드 및 정수 인코딩

# %%
# 데이터 로드

import xlrd

# 해당 파일은 네이버 영화 리뷰 데이터입니다.
workbook = xlrd.open_workbook("test.xlsx") 

# test
worksheet = workbook.sheet_by_index(0) # test sheet에 접근합니다.
test = worksheet.col_values(1) # document 열에 접근

# %%
#import xlrd

#workbook = xlrd.open_workbook("test.xlsx")

# train
#worksheet = workbook.sheet_by_index(0) # test sheet에 접근합니다.
#test = worksheet.col_values(0) # 기본 data
#test_morpheme = worksheet.col_values(1) # kkma를 이용하여 형태소 분석한 결과
#test_syllable = worksheet.col_values(2) # 음절별로 나눈 결과

# %%
test
# Out:
# ['노래 가 너무 적 음',
#  '돌 겠 네 진짜 황 숙아 어크 공장 그만 돌리 어 라 죽 는 다',
#  '막노동 체험 판 막노동 하 는 사람 이 ㄴ데 장비 를 내가 사 아야 되 어 무엇 이 지',
#  '차 악차 악차 악 정말 이래 서 왕국 을 되찾 을 수 있 는 거 야',
#  '시간 때우 기에 좋 음 도전 과제 는 시간 이 면 다 깨 ㄹ 수 있 어요',
#  '역시 재미있 네요 전 작 에서 하 ㄹ 수 없 었 더 ㄴ 자유 롭 ㄴ 덱 빌딩 도 좋 네요',
#  '재미있 었 습니다',
#  '은근 쉽 지만 은근 어렵 ㄴ 게임',
#  '베 ㅈ 스 다 이 개 ㅐ 끼들 아 아 시작 하 ㄹ 때 체스 판 돌아가 는 거 분 동안 번 보 았 더 나 ㅈ ㄴ 빡 치 네 진짜 무 한로 딩 버그 안 치 어 고치 냐 겜 하 지 말르 아 는 걸 냐',
#  '시간 분 동안 스트레스 다 풀리 ㅁ ㄹ ㅇ',
#  '걍 겜 임 계정 을 못 만들 어 미치 ㄴ 겜',
#  '관람객 호랑이 불가',
#  '재미 쩡 초반 에 좀 힘들 어 여 도트 라서 조아',
#  '포켓볼 도 몰르 았 는데 이 것 으로 배우 어 갈 ㅂ니다 심심 하 ㄹ 때 하면 좋 아요 컴퓨터 상대 하 는 거 제대 로 이기 어 보 고 싶 은데 잘 안되 네요',
#  '트레이 아크 사랑 하 어요 핰 핰',
#  '좆 망 겜 하 지 마 무슨 처음 에 키 자마자 매칭 이 왜 렙 하고 매칭 되 냐',
#  '뭐 랄 까 아 다 크 소 우리 하 는 느낌 이 에요 죽 으면 돈 다 날라가 는 방식 렙 업 하 면서 무한 반복 이 ㄴ 거 같 은데 재미있 습니다 클래스 도 은근 많 은 거 같 고 또 캐릭터 를 계속 추가 하 ㄹ 예정 이 ㄴ가 같 고 그리 고 하 ㄹ 요소 하 고 매번 덜 ㄴ 전도 바뀌 고 재미있 습니다 돈 이 아깝 지 않 다고 생각 들 네요 ㅊ ㅊ',
#  '원하 는 거 보 실리 어 면 홈페이지 가시 어서 패치 를 사 시 어야 하 ㅂ니다 패치 가 만원 이 라 사실상 만원 주고 게임 을 사 는 것 이 ㄴ데 ㅁ 좋 던데요',
#  '안해 썩 을 까 아 진 그냥 대충 슥슥해 도 되 더니 에 서 판때기 를 직접 사용 하 는데 판 을 밟 는 순간 스 어 있 는 땅 이 변하 어 버리 니까 뭔 가 아 억울 하 면서 하 기 싫 어 지 었 음 그리하 여도 일단 이놈 을 못 잡 으면 왠지 못 깨 서 안하 는 것 같 아서 깨 고 접음',
#  '우 웩',
#  '로지텍 마우스 가 드디어 일한 게임 매크로 없 는 흑우 없제',
#  '디스플레이 에 다소 버그 가 있 지만 게임 자체 는 훌륭 하 다',
#  '압도적 긍정적 이 든 뭐 든 나랑 안 맞 으면 노 잼 이 라는 것 을 새삼 느끼 게 하 어 주 ㄴ 게임',
#  '명중률 면 인간적 으로 맞 아야 하 는 거 아니 냐',
#  '나 는 되게 재 밋 게 햇넹 ㅋㅋㅋㅋ 딱 키 ㄹ 링 타임 용 으로 적당 하 ㄴ 듯',
#  '쓰레기 게임 절 때 사 지 말',
#  '재미있 는 게임 이 지만 티 어 올리 는데 너무 오래 걸리 ㅁ',
#  '걍 이 겜 하 실리 어 면 어리 어 울 니까 무료 겜 인 하 세요',
#  '이 게임 의 단점',
#  '처음 에 는 그냥 그런 횡 스크롤 액션 게임 정도 이 었 으나 단계 가 넘어가 ㄹ수록 개발자 의 재치 가 엿보이 는 게임 이 네요 중국 도 게임 이 많이 발전 하 었 다는 것 을 느끼 ㄹ 수 있 는 게임 이 었 습니다',
#  '아 아 중독성 있 네요 한번 하 면 멈추 기 가 힘 드 ㅁ',
#  '개 슈 레 기 게임',
#  '이 게임 은 정말 좋 은 게임 ㅋㅋㅋ',
#  '세일 을 들 ㄴ 몇 퍼센트 를 하 더라도 사지 말르 아 이 한마디 이 면 되 ㄹ 듯하 다 사 면 그 순간 넣 ㄴ 호 갱 이 되 ㄴ 거 이 다 무료 로 뿌리 는 것 을 받 았 다면 카드 만 받 아라 나 는 이것 이 어떻 게 팔리 게 됬 늘 ㄴ지 그 게 참 궁금 하 다',
#  '무료겜 이 적당 하 ㅁ',
#  '컴퓨터 로 하 지 마세 요 걍 플스 로 하세 요 혼자 이상 하 ㄴ 데 낑기 어서 말 도 안되 게 버벅 거림 시작 하 ㄴ 지 시간 만 지우 어 버리 ㅁ니다 내용 을 보 기 전 에 조작 감이 쓰레기 이 ㄴ 패드 랑 키보드 다하 어 보 았 는데 혼자 이상 하 ㄴ 데 낑기 ㅁ',
#  '레이싱 을 즐기 ㄹ 수 있 다 다른 오브젝트 와 차량 을 파괴 하 ㄹ 수 있 으며 드리프트 가 조금 힘들 다 레이싱 이 질리 ㄴ다면 트랙 이 너무 쉽 다면 마이 시티 를 통하 어서 자신 의 트랙 을 만들 ㄹ 수 있 습니다',
#  '훌륭 하 ㅂ니다 저 ㄹ 대 마 코 해',
#  '이거 어 어 뜨 게 하 ㄴ 굳 어 하 ㅁ',
#  '계속적 으로 멈추 ㅁ 현상 발생 왠 만하 면 전작 도 재밌 어서 할려 하 었 는데 도저히 불가능 하 여 포기',
#  '밸브 가 만들 ㄴ 게임 이 ㄴ가요 뭔 가 하프 라이프 같 은 느낌 이 드 고 그래픽 이랑 상대 적 이 외계 생명체 이 고 협동 게임 이 라니 역시 같이 하 니까 재밌 네 여 추천 하 ㅂ니다 무료겜 이니 더 좋 네 여 ㅎㅎ 게다가 질 ㄹ 양 하 고 싸우 는 게임 ㅋㅋㅋㅋ',
#  '재미 있다 좀비 모드 라 걸 나 하 는 모드 도 지원 하 지만 알 는 사람 없이 혼자 하기 에 는 조금 모자라 ㄴ 느낌',
#  '심각 하 게 노 잼 이 ㅂ니다',
#  '처음 부터 긑 까지 현 질만 유도 하 는 게임 어느 시점 이 되 면 절대로 이기 ㄹ 수 없 는 사람 들 하 고 만 팀 매치 가 되 ㅁ 걍 하 지 말 아야 하 ㄹ 게임 게다가 서버 도 엄청 느림 돈 밖 에 모르 는 게',
#  '갓 겜 세일 하 ㄹ 때 꼭 사셈',
#  '베데 스 다 오 아 돼지 새끼 법규',
#  '마테 체로 썰 고 다니 는 것 이 너무 재밌 다 없 더 ㄴ 스트레스 도 풀리 는 기분',
#  '실제 카지노 에서 포커 를 하 는 듯하 ㄴ 기분 이 듣 어서 너무 좋 았 음 정말 잘 만들 ㄴ 것 같 아요',
#  '왜 도트 겜 이 ㄴ데 프레임 이 많이 끊기 는 거지 게임 좀 해보 고 싶 은데',
#  '게임 자체 는 외국섭 만 보 았 을 때 는 좋 은데 좆 목 잼 민 이 들 ㄹ 여왕벌 이 삼위일체 를 이루 는 ㅆ ㅉㄸ 한국 섭은 가 지 않 는 것 이 정신 건강 에 이로 움 한 국섭 듣 어 갈리 어 면 절차 가 금융 보안 프로그램 설치 급 이 다',
#  '쓸모없 는 공군',
#  '솔 까 아 무료 라고 하기 에 는 퀄 개 쩜',
#  '서 든 어택 표절 하 ㅁ ㅋㅋㅋㅋㅋ 서 든 어택 도 총 쏘 고 움직이 고 한방 에 죽 는데 이겜 이 배끼 ㅁ 에 혀 개노잼망겜 이 다 이렇 지 븅 쉬 개 ㅁ ㅋ',
#  '허 난 울 ㄴ다',
#  '퇴근 하 고 게임 은 하 고 싶 은데 빡겜 하 ㄹ 기운 은 없 고 축 늘어지 어서 쉬 어 ㅁ 쉬 어 ㅁ 한 게임 극 후반부 까지 진행하 었 지만 엔딩 이 얼마 안 남 았 음에도 참 지 못하 고 찍 싸 었 다 드래곤 볼 좋아하 니깐 머 하 는 동안 나쁘 지 는 않 았 지만 남 에게 추천 은 도저히 못 하 겠 다',
#  '레벨 하나 깨 ㄹ 때 마다 해당 멜로디 를 다시 확인 시키 어 주 는 것 이 신경 을 과하 게 자극 하 ㅂ니다 그렇 다고 딱 히 합주 가 자극 이 적 은 건 아니 었 더 ㄴ 것 같 아요 퍼즐 난이도 는 서서히 높 아 지 다가 갑자기 차원 수가 하나 늘 어 버리 네요 전 못 하 겠 어요',
#  '게임 더럽 게 어렵 다 그래픽 은 좋 더 라 노 잼',
#  '탈출 하 는 거 에 만 열중 하 고 외 에 아무 생각 안 듣 어서 좋 다고 하 기 는 애매 하 어요',
#  '삭제 하 어도 다시 생각나 서 하 게 되 네요',
#  '한패 가 없 다 싯 팔',
#  '점점 나 가 가해자 이 고 악마 가 피해자 같 다 걍 떄려 부시 어야지 이 히 힣',
#  '카악 퉤',
#  '싱글 미션 이 더 많 았 으면 하 는 아쉬움 이 남 는 다 홈 월드 를 플레이 하 ㄴ 기억 이 없 다면 이 시리즈 를 구매 하 ㄹ 이유 가 있 을까 올드 팬 이 아니 라면 구매 를 하 지 않 는 것 이 더 낫 을 수 도 있다 이 게임 을 대체 하 ㄹ 만하 ㄴ 게임 들 이 많 다',
#  '머리 쓰 는 게임 퍼즐 게임 좋아하 는 유저 이 라면 필 구',
#  '쿠키 크 ㄹ 리 커 어 의 스팀 판 굳이 키 어 놓 지 않 아도 돈 이 차 곡 차 곡 쌓이 니 웹 게임 처럼 어쩌다 한번 씩 만 들어오 아서 업그레이드 하 어 주신 뒤 나가 는 것 만 으로 도 충분히 즐기 ㄹ 수 있 을 것 이 ㅂ니다',
#  '들이 하 는 거 보 고 받 았 는데 너무 스토리 가 짧 고 너무 쉽 다 더 어렵 게 만들 어 주 거나 스토리 를 늘리 어 라 게임 사 ㄴ 것 이 아깝 어 질 ㄴ다',
#  '열차 루트 같이 묶 어서 팔 는 것 이 좋 을 것 같 네요 초보자 들 은 진짜 헤매 거든요',
#  '뿡 밑 탙',
#  '구입 하 고 몇 년 째 하 ㄹ 줄 모르 아 안하 다가 울트라 와 이드 모니터 구입 후 에 테스트 삼 아 해보 았 는데 눈깔 돌아가 는 구 만 레이싱 은 역시 울트라 와이드 모니터 로 하 어야 겠군 근데 낳 ㄴ 역시나 실력 이 늘 ㄹ지 않 는 구 만',
#  '장 국산 게임 예쁘 ㄴ 일 러스트 단 빠져들 ㄹ 것 만 같 은데 동시 에 몰입 이 이상 하 게 안 되 는 스토리 부분적 이 ㄴ 국어책 읽기 수준 의 연기 를 하 는 다수 의 캐릭터 기본적 으로 재미 가 없 음 호 ㄴ 자만 커플 없 는 영조',
#  '배경 화 이 면 보 려고 게임 별로 안하 게 되 ㅁ',
#  '이 게임 은 개 를 보 는 것 뿐 만 아니 라 무려 개 를 쓰다듬 을 수 도 있 답니다 제목 이 게임 을 반 도 표현 못 하 는 게임 이 죠',
#  '난이도 가 너무너무 높 다 스테이지 부터 절망 을 맛보 게 되 ㄹ 것 이 다 장르 가 슈팅 이 ㄴ 만큼 은 매우 좋 다 창 모드 고정 이 안되 는 것 이 아쉽 다 알트앤터 로 일일 히 설정 하 어야 하 ㅁ',
#  '두 명이 서 멀티 하 다가 배 아프 아 뒤지 ㄹ 뻔 하 ㅁ 웃음 으로 운동 하 ㄴ다는 얘기 를 실감 하 ㅁ 부 ㄴ 동안 미치 ㄴ 거 마냥 웃 었 더니 배 가 찢어지 ㄹ 거 같 고 광대뼈 가 쪼개지 ㄹ 거 같 아서 그만두 ㅁ 웃기 싫 은데 도 웃기 어서 끄 ㄴ 거 임 ㅇ ㅇ',
#  '내가 이 게임 뜨 ㄹ 거 라고 하 었 지 근데 이 아니라 이 었 더 ㄴ 거 에 요 눈물 이 나 었 어요',
#  '언어 압박 이 심하 ㄴ 게임 이 ㅂ니다 생각 보다 어렵 고 재미 는 그다지 못 느끼 는 게임 이 라고 생각 하 ㅂ니다',
#  '훌륭 하 ㄴ 작품 이 ㅂ니다 단점 은 스토리 가 너무 짧 습니다 장점 은 역시 툼 레이더 이 ㅂ니다',
#  '재미 는 있 는데 사람 이 너무 없 다',
#  '조작 감이 좋 지 못하 어요',
#  '어떤 게임 을 원하 어서 이 게임 을 구매 하 는지 정말 잘 알 ㄹ 것 같 은데 이 건 어떤 식 으로 든 그 보다 못 하 ㄴ 게임 이 ㄹ 것 이 ㅂ니다 그냥 노 잼 세일 을 하 더라도 구매 하 지 않 는 것 이 더 좋 다고 생각 하 ㅂ니다',
#  '재미있 어요 오 아 울',
#  '첫 엔딩 노멀 보 았 는데 너무 재밌 게 하 었 습니다 플레이 타임 은 비록 짧 지만 확 빠져들 네요',
#  '로켓 을 조종 하 어서 무사히 착륙 시키 는 게임 이래 뵈도 어렵 다만 폭 팔 하 는 이펙트 가 의외로 멋 있음 난 무료 행사 때 얻 음',
#  '세상 에서 제일 아깝 ㄴ 분 이 었 습니다',
#  '시간 이 면 평가 하 어도 되 어요 아 아 님 더하 고 오 아요',
#  '타격 감 은 히오스 보다 더 좋 음',
#  '처음 에 는 컨텐츠 가 없 는 줄 알 았 다가 하 면 하 ㄹ 수록 하 ㄹ 것 이 많 은 게임',
#  '알 니 발 내 는 것 은 좋 은 데 없 어도 게임 은 하 ㄹ 수 있 게 발매 하 어야 되 ㄹ 거 아냐 같 네 진짜 가격 도 존나 게 비싸 면서 기능 은 창작 마당 보다 도 못하 고 빙 융 시 시인 색 ㄱ ㄱ 긱 듣',
#  '삶 은 서로 를 죽이 며 살아가 ㄴ다 자연 과 인간 의 잔혹 하 ㅁ 을 새롭 ㄴ 관점 에서 바라보 는 게임',
#  '덜 ㄴ 파충 들 은 이 게임 을 해 이 라',
#  '가 아 성비 최고 의 게임 이 ㅂ니다 치 ㄴ 구들 이랑 즐기 기 좋 습니다',
#  '임 게임 다운 받 았 는데 실행 안 되 어요 다이렉트 문제 로 실행 이 안 되 어 스 어 다이렉트 도 재 설치 하 고 최신버젼으 로 해보 았 는데 소용없 네요 게임 들어가 다 팅 길 ㅂ니다',
#  '서버 에 사람 이 없 음 중국인 들 때 매 다 접 은 듯',
#  '병 맛 으로 하 는 게임 ㅋㅋ ㄱ 가격 에 비하 어 개꿀',
#  '멀티 플레이 만큼 은 배필 급',
#  '예전 테마 병원 을 생각 하 고 구입 하 었 는데 오 아 잠깐 하 ㄴ다고 하 었 는데 오후 시 에 시작 을 하 었 는데 새벽 을 넘기 고 있 더 라는 허허허 추천 하 ㅂ니다 문 상 으로 충전 하 어서 사 세요',
#  '사이버 멀미 를 느끼 고 싶 다면 추천 게임 여러 가지 해보 았 지만 이 게임 이 처음 이 다',
#  '진짜 ㄹ ㅇ 꿀 잼 게임 이거 하다 보 면 시간 갈 는 줄 모름 모드 까지 깔 아서 하 면 더 꿀 잼',
#  '찬란히 빛나 는 남자 의 상징 그 길 고 짧 은 여정 은 개뿔 이 그냥 바바리 맨 의 안 잡히 기 놀이 겜',
#  '재밌 음 버그 도 없 어 지 고 중세 시대 좋아하 ㄴ다면 한번쯤 해보 ㄹ 만하 ㅁ 처음 에 나오 ㄹ 때 버그 좀 제대 로 고치 어서 나오 았 었 으면 좋 았 었 을 터 이 ㄴ데',
#  '지금 하 어도 꿀 잼 이 ㄴ데 지금 하 어도 멀미 남 으아 못하 게 썽 ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ',
#  '쩔 는 게임 이 ㅂ니다 꼭 해보 세요 더 이상 의 자세 하 ㄴ 설명 은 생략 하 ㄴ다 왜냐고 요 스포일러 거들 ㄴ',
#  '부모님 을 보여드리 었 더니 아주 좋아하 시 ㅂ니다 근데 어머니 는 고래 가 무섭 어서 중간 에 포기 하심 크 기 는 크 더 라고요 ㅎㅎ 물고기 는 건드리 면 도망가 고 말미잘 은 건드리 면 숨 어 버리 ㅂ니다 접대용 으로 좋 아서 환불 않 고 계속 가지 고 있 을 생각 이 네요 ㅋㅋ',
#  '전작 이 개 띵 작이 어 었 지만 이 게임 은 그냥 망하 었 다 물론 후속 작도 ㅈ 망하 었 다 사지 마라 걍 차라리 복 돌 로 해 이 라',
#  '나 가 원하 는 노래 로 리듬 게임 을 하 ㄹ 수 가 있다 이 것 으로 도 대만족',
#  '꺼지 어 라 고인물 쉑 듣',
#  '저 는 반값 에 구매 하 었 습니다',
#  '프레임 은 고정 으로 계속 나오 는데 게임 자체 문제 로 계속 조금씩 버벅 이고 끊기 ㅁ 그래픽 도 ㅈ 구림',
#  '알 니 왜 키 안주 이 고 난리 시발 게임 어떻 게 하라 이 고 먼저 구매 하 ㄴ 사람 호 갱 댓 구 연',
#  '장기 에프 가슴 털',
#  '실행 안 되 어 늘 ㄴ 좃 망 겜',
#  '치 ㄴ 구들 이랑 같이 하 면 재미있 는데 멀미 가 너무 심하 어서 오래 못하 겠 음',
#  '얼엑으 로 내놓 고 개발 중단 먹 튀',
#  '너무 허무 하 ㅁ 그리고 주인공 그 특유 의 인생 혼자 다 살 ㄴ 허세 말투 짜증나 ㅁ ㅋㅋㅋㅋ',
#  '네 코 파라 엑스트라 게임 시간 분량 을 분 으로 축약 하 ㄴ 애니매이션입니 다 비교 적 짧 은 시간 이 라 느긋 하 게 보시 ㄹ 수 있 습니다 앤딩곡 이 좋 아요 메이플 도 좋아',
#  '나 가 디지 세요 유저 좆 목질 꼬라지 뉴 비 배척 오지 는 겜',
#  '내 인생 최고 의 생일 선물',
#  '엣지 보다 훨 좋 다',
#  '업데이트 전 에 는 오버 쿡 보다 쉽 고 가 면 갈수록 난이도 에 변동 이 없 길래 많이 실망 을 하 며 난이도 가 좀더 높 게 나오 면 좋 겠 다고 생각 을 하 었 었 는데 점수 대가 하나 추가 되 면서 그리하 여도 만족도 가 올라가 었 다 근데 너무 점수 대가 에바잖 아',
#  '화면 전환',
#  '전 쏘쏘 하 게 하 었 네요 시간 정 도 즐겁 게 하 었 으면 이 정도 가격 만족 하 ㅂ니다 다 만 나중 이 되 면 변수 는 거의 없 어 지 고 습격 하 어 오 는 부족 들 만 강제 로 강하 게 하 는 느낌 이 너무 강하 었 어요 그 때 부터 재미 가 확 떨어지 니 뭔 가 아 다른 방법 도 추가 하 어야 하 ㄹ 것 같 습니다',
#  '웨 ㄹ 메 이드 플랫 포 머 게임 조작 감 브금 액션 맵 구 성 스토리 개인적 으로 전부 다 맘 에 듣 었 음 옛날 게임 니 ㄴ 자가 이 델 ㄴ 과 매우 비슷 하 ㄴ 데 상위 호환 이 라고 보 ㄹ 수 있음 어리 ㄹ 적 페 미 컴 게임 의 향수 를 느끼 고 싶 은 사람 들 은 필 구하 어야 하 ㄹ 게임',
#  '재밌 다 고인물 많 다 접 어야 겠당',
#  '빠요 에 는 너무 많 음',
#  '정말로 잼 있 어요 친구 하 면 더 잼 있다',
#  '울 ㄹ 삼촌 이 빠지 ㄴ 겜 근데 낳 ㄴ 노 잼',
#  '재밌 으나 다른 사람 들 하다 가 메 ㄴ 탈 나가 는 거 보 는 것 은 더 꿀 잼',
#  '상당히 지루 하 ㄴ 오픈 월드',
#  '게임 이 재밌 기 는 한데 범인 추론 하 는 과정 이 너무 억지 임 증거 없이 그냥 추론 만 으로 범인 잡 는 것 이 너무 위험 하 지 않 나 싶 음',
#  '남자 의 로망',
#  '노 잼 이 ㄴ데 팀 포의 코믹 스럽 ㅁ 을 따라하 고 싶 었 나 본데 팀 포의 코믹 하 ㅁ 은 캐릭터 의 익숙 하 ㅁ 이 크 ㄴ 바탕 을 이루 고 있 어서 흉측 하 고 잔인 하 ㄹ 뿐 이 ㄴ 캐릭터 와 연출 로 는 절대 안 되 ㄹ 듯',
#  '은 이 다 변 하 ㄴ 거 없 다 다 들 도망치 어',
#  '재미없 음 처음 에 는 오 헬기 드 론 탱크 드 론 이런 거 조종 하 어서 나름 괜 차 었 나 싶 었 는데 하 면 하 ㄹ 수록 재미 가 없 어 짐 헬기 딱 벌 ㄴ 등 장함 탱크 가 아 반 이 고 컴퓨터 아군 전혀 도움 안됨 이것 을 외 어 하 는지 모르 겠 음 그 냥 묶음 떨이 로 하 어서 사 었 는데 엉 아니 ㅁ',
#  '아 아 제작자 가 버리 ㄴ 게임',
#  '게임 은 꿀 잼 이지만 사람 이 너무 없 다 멀 ㄹ 티 하 는 것 이 매우 힘 드 ㅁ',
#  '이사 양 에 이 가격 에 이런 게임 구하 기 어렵 습니다 이 것 은 꼭 사 세요',
#  '모든 도전 과제 완료 성공 하 ㄴ 킥 스타터 중 하나 인 웨이스트 랜드 클래식 하 ㄴ 서양 알 ㄹ 피지 장르 를 좋아하 ㄴ다면 꼭 해보 아야 하 ㅂ니다 물론 아쉽 ㄴ 점 도 있 지만',
#  '음 걍 공짜 이 라는 것 도 갓 겜 이 ㄴ데 재미 도 있슴 하지만 쫄 ㄹ 보 는 하 지 마 셈 존시 나 무서움',
#  '이 게임 이 다른 게임 과 차별화 를 두 ㄴ 것 이 있 다면 그 건 이 게임 에 는 점프 가 없 다는 것 이 다 생존 겜 이 ㄴ데',
#  '엉성 하 ㄴ 컷 씬 지루 하 ㄴ 전투 사이드 퀘스트 부족 다른 지역 을 퀘스트 에 따르 아서 갈 ㄹ 수 있 으나 퀘스트 를 다 깨 ㄴ 후 에 는 가 지 못하 는 지역 존재 컷 씬 장면 에서 주인공 의 이유 없 는 얼굴 검 은 칠 등 차 플레이 하 고 싶 지 않 는 게임 이 ㅂ니다',
#  '어렵 습니다 재밌 습니다',
#  '서 든',
#  '게임 좆 같이 만들 네 시 발 멀티 좀 해보 자 하 ㄹ 때 마 다 팅 기 어 개 같 은 게임 이',
#  '이것 이 끝',
#  '맨 탈 박살나 ㅁ',
#  '개 답답 씹노 잼 트레일러 에 낚이 ㅁ',
#  '진짜 액션 성 플래 이 타입 바뀌 ㄴ 거 참고해볼려해 도 번역 떄 매 진짜 하 기 싫 어 지 ㄴ다',
#  '내가 이 게임 을 왜 사 었 을까 지금 까지 산 게임 중 에 가장 최악 이 다',
#  '하 ㄴ 키보드 로 두 명이 스 어 하 ㄹ 수 있 는데 사 고 싶 으면 사 든가 뭐 원 이 라서 사 었 지만',
#  '출시 되 ㄴ 지 년 이 지나 었 지만 지금 도 나 에게 있 어 이 게임 을 넘어서 는 멀티 플레이어 늘 ㄴ 없 다',
#  '게임 은 정말 재미있 고 좋 은데 한글 번역 을 하 ㄹ 꺼 이 면 제대로 하 어 주 세요',
#  '이 게임 을 하 고 구매 를 결심 하 게 되 었 습니다 고맙 어요 네 코 파라 이브',
#  '트럼프 님 이나 수술 하 어 드리 ㅂ시다',
#  '스텐 리 재밌 게 하 었 으면 재밌 게 하 ㄹ 만하 ㅁ',
#  '재밌 다 팬 심 으로 하 ㄴ 듯',
#  '오 아 내가 해본 퍼즐 게임 중 제일 어렵 다',
#  '를 지원 안 하 고 랑 말 ㄴ 지원함 화질 극 혀 ㅁ 화면 짤리 ㅁ',
#  '이거 로그 인 이 안되 는군요 이름 짓 기 힘 드 ㅁ',
#  '오크 관리 하 는 시스템 이 너무 지나치 ㄹ 정 도로 분량 이 많 음 개 지역 이상 점령 하 는 거 직접 하 었 으면 오크 성애 자 이 ㅁ',
#  '게임 을 실행 하 ㅁ 과 동시 에 렉 이 걸리 ㅂ니다 그런데 웃기 ㄴ 것 은 정작 본 켐페인 에 들어가 면 렉 이 걸리 지 가 아 않 습니다 메인 화면 에서 렉 이 걸리 지 않 게 하 어 주세 요 게임 을 사 고 나 서 정 낙 게임 을 못하 고 있 습니다 ㅠㅠ',
#  '알 니 이것 이 안되 네 알 니 이것 이 되 네',
#  '내가 헤 보 았 을 때 는 현질 유저 들 이 뉴 비 를 학살 하 는 장면 을 보 았 는데 존나 미치 었 다',
#  '무섭 고 재미 가 없 다 마지막 에 는 짜증 만 가득',
#  '음 돈 벌 려고 만들 ㄴ 게임 이 아니 네 정말 잘 만들 기 는 하 었 는데 뭔 가 아 아니 다 싶 네 그냥 자기 맘 에 들 게 만들 면 되 는 거지 뭐 까지 찍 는 동안 재 밋 것 이 잘 하 었 어요 나중 에 컨텐츠 더 추가 되 면 그때 다시 보 아요',
#  '너무 어렵 ㄴ 거 빼 고 다 너무 좋 은 게임 만들 시 느라 고생 하 시 었 읍니다',
#  '구림',
#  '서버 관리 가 너무 안되 ㅂ니다 피씨방 에서 접속 하 어도 렉 은 기본 이 고 튕기 기 까지 하 니 너무 힘들 네요',
#  '운수 좋 은 날 일 때 하세 요 친구 랑 하면 더 재미있 습니다 친구 가 없 다고요',
#  '현재 시간 가량 플레이 중 이 ㅂ니다 네 시간 동안 못 자 었 습니다',
#  '왜 멀미 나 냐',
#  '게임 이 뭐 하 ㄹ 것 이 없 어요',
#  '진 엔딩 보 았 으니깐 하 는 말 이 ㄴ데 프롬 시발 놈 들 아 아 이것 이 게임 이 냐',
#  '특이점 누르 면 후회 하 ㅁ',
#  '환불 안해 주면 박 현준',
#  '하 ㄹ 겜 이 없 을 때 하 려고 사 었 는데 이거 하 느라 다른 겜 접음',
#  '사람 이 없 다 혼자 하면 재미 없 음 스토리 없 음 그리고 삭제 이 것 으로 설명 끝',
#  '컨텐츠 얼마 없 고 하 ㄹ 거 없 어요',
#  '내 로그 라이크 모드 어디 가 었 는데',
#  '한국어 패 하 지 버전 이 없 다는 것 이 가장 아쉽 습니다 한글 패 하 지 꼭 좀 나오 았 으면 좋 겠 습니다',
#  '제발 젠 챕터 좀 주 세요 ㅠㅠ',
#  '낙지 볶음 시뮬레이터 개꿀 잼 내 인생 게임',
#  '충성 충성 싸돌아다니 기 좋아하 면 갓 겜',
#  '이런 류 의 캐쥬 얼 게임 좋아하 는데 후속 작 은 없 는 걸 ㄴ가요 ㅠ',
#  '재밌 기 는 한데 이 게임 의 가장 크 ㄴ 문제 는 컨텐츠 가 너무 한정적 이 라는 점 이 다 계속 똑같 은 거 만 하 게 되 고 금방 질리 게 되 는 단점 이 있 다 혹시 이 게임 을 사 시 ㄹ 분 이 라면 이 게임 은 딱히 안하 는 것 이 낫 다는 점 을 말씀드리 고 싶 다',
#  '재미 는 있 는데 도전 과제 가 사람 을 찝찝 하 게 만들 네',
#  '좀비 가 사칙 연산 하 는 게임 머리 가 좋아지 는 느낌 이 네요 팁 기호 는 나누기 이 ㅂ니다 은 이거 땜 에 난이도 가 급상승',
#  '권총 쏘 는 재미 하나 는 원탑 이 다 이 말 이 야',
#  '한 턴 만 더 분만 더 한 시간 만 더 하루 만 더',
#  '엔딩 조건 빼 고는 전작 이랑 뭐 가 달리지 ㄴ 거 야',
#  '정말 그래픽 게임 성 뭐하 나 빠지 지 않 는 쓰레기 게임 이 네요',
#  '오른쪽 팔 이 펌핑 이 되 었 다 마우스 회사 에서 마우스 를 전부 파괴 하 려고 만들 ㄴ 프로그램 이 ㄴ가 보다 원래 마우스 클릭 횟수 가 수명 아니 냐 아 아 팔 아 파도 전 과제 순식간 에 클리어 하 ㄴ 것 은 좋 다',
#  '개 좋 음',
#  '바탕 화면 꾸미기 에 아주 좋 음',
#  '아 아 진짜 컨베이어 벨트 깔 다가 각종 방향 버그 그리고 시스템 작동 시 킬려 이 면 온갖 오류 가 넘치 는데 빡쳐 서 접 는 다',
#  '가 아 멍청 하 어서 싫 다',
#  '차라리 유로 트럭를 하 세요',
#  '프레임 드랍 너무 심 하 ㅁ',
#  '다듬 어야 하 ㄹ 것 이 너무 많 음 타격 감 이나 탄 속 버그 등',
#  '퍼즐 은 좋 은데 너무 터무니 없 는 곳 에서 푸 어 즐 조각 들 이 나오 ㄴ다 그리 고 막히 었 다 싶 으면 무작정 더블 클릭 을 해보 면 확대 되 면서 예상 하 지 못하 ㄴ 곳 이 있 거나 렌즈 를 무조건 써보 아야 하 ㄴ다',
#  '무료 체험 판 해보 았 는데 게임 은 잘 만들 었 는데 못 사 겠 네요 너무 잘 만들 어서 너무 무섭 어 ㅜㅜ',
#  '단점 강제적 으로 보여주 는 컷 신이 많 음 플레이 분 도 안 되 어 스 어 보이 는 캐릭터 의 부자연 스 러 울 ㄴ 움직임 더러운 조작 감 장점 이 모든 걸 ㄹ 분 도 안 되 어 스 어 느끼 ㄹ 수 있 어서 환불 결정 이 빠르 ㅁ',
#  '오픈 월드 에서 경찰 과 도둑 하 는 굴 잼 게임 이 ㄴ데 커스 터 마이 징 도 무궁무진 하 고 좋 은데 게임 을 망치 ㄴ 이유 운영 이 망치 었 습니다 페 이투 윈 고인물 많 음 개인적 으로 이런 느낌 의 오픈 월드 게임 이 또 나오 았 으면 좋 겠 읍니다',
#  '고대 의 전투 를 재현 하다 는 본래 의 재미 는 여전 하 다 하지만 내정 이 라고 하 ㄹ 만하 ㄴ 것 이 없 어서 반복 전투 에 지겹 어 지 ㄹ 때 매력 이 다하 는 느낌 이 다',
#  '아쉽 어요',
#  '이것 이 바로 시간 을 거스르 는 자',
#  '어우 중국 발 미세 먼지 가 게임 도 더럽히 네 착 짱 죽 짱 은 진리 이 다',
#  '흠 현실성 이 굉장히 뛰어나 고 흔 근 히 세력 에 대하 ㄴ 감정 싸움 은 물론 특히 일본 과 우리나라 의 감정 싸움 이 특히 매우 가하 ㅂ니다 그래서 그렇 ㄴ 것 을 까 아요 아니 면 이 게임 이 완성도 가 굉장히 높 아서 그러 ㄴ 거 이 ㄹ까요 매우 재미있 습니다',
#  '네 코 파라 시리즈 는 스팀 야 겜 필수 목록 순위 이 ㅂ니다',
#  '뭔 가 깨 기 어렵',
#  '몰 러 그냥 배 고 보다 재밌 다 헤 헿',
#  '그래서 여우 새끼 는 어딨 는 거 야',
#  '리듬 게임 이 ㄴ데 리듬 이 맞 지 않 는 신 기한 게임',
#  '싱글 플레이 방방 뛰 면서 연속 키 ㄹ 을 땋 ㄹ 때 의 쾌감 은 진짜 인정 타임 어택 그리하 여도 속도감 은 속도감 이 ㄴ지라 도전 욕구 는 생기 었 었 다 그리하 여 생기 었 었 지 야발 멀티 플레이 안해 봄',
#  '배경 음악 굿',
#  '나 만 이 게임 오른쪽 컨트롤 키 없 어서 못하 ㅁ',
#  '웜 커 어 엽 그 ㄴ데 도움말 도 없 고 길 찾 기 넘 힘 드 ㅁ 퀘스트 깨 는 것 보다 찾 으러 돌아다니 는 것 이 시간 더듬',
#  '처음 에 목매 ㄴ 남자애 보 고 있 으면 눈뜨 ㅁ',
#  '솔직 하 게 미 연시 작품 그리 자 ㄹ 하지 를 않 는데 네 코 파라 사쿠라 스피릿 등 모두 시간 이것 만큼 은 진짜 명작 같 았 다 처음 으로 미 연시 이 라는 장르 에 빠져들 ㄴ 작품 이 였 다',
#  '세이브 파일 이 스팀 클라우드 에 동기화 가 안되 는데 그것 만 어떻 게 처리 되 ㄴ다면 괜찮 을 거 같 아요 스토리 진행 하 는데 영어 가 딸리 어서 시간 정도 걸리 네요 분량 이 조금 짧 은 느낌 이 듣 었 고 급 전개 이 라는 느낌',
#  '무섭 었 습니다 후 덜덜 간 이 커지 면 다시 해보 겠 습니다',
#  '쟝 게 파',
#  '영어 알 아야 재밌 다 구리 ㄴ 게임 아니 ㅁ 좋 음',
#  '컨텐츠 가 없 네',
#  '사람 이 없 다',
#  '비추하 ㅂ니다 오픈 첫날 주말 내내 서버 닫 아 두 는 기술력 에 감탄 하 고 갈 ㅂ니다',
#  '옛날 에 많이 하 었 었 는데 다시 해보 니까 여전히 재밌 었 습니다',
#  '길 찾 다 개 빡 하 지 네 길치 랑 성격 급 하 ㄴ 사람 은 하 지 말길',
#  '한 놈 몰 ㄹ 빵 하 어서 키우 다가 죽 으면 메 ㄴ 탈 도 검 투사 대가리 날라가 듯이 날라가 ㅁ',
#  '암 워킹 인 더 레인',
#  '망겜 이라 그리 말하 었 거늘 어떤 초딩 이 부들부들 거리 면서 비추 를 눌르 었 는가',
#  '강렬 하 ㄴ 네온 사인 에 눈 이 멀 어 버리 었 습니다',
#  '서로 죽이 며 지랄 하 는 게임',
#  '탭 키 로 유저 정보 보 면 항상 열 에 네다섯 명 은 애 니 프 사 아 달 고 있 는 씹덕 들 어디 서 나 아 한글 만 고집 하 며 외국인 에게 당 당하 게 한글 로 대화 하 려 하 는 코 충이 캐주얼 에서 도 눕스거리 며 뉴 비 배척 정 치질 하 는 고이 다 못하 어 썩 은 물 들 와 ㄴ 죠 ㄴ 뭐하 나 빠지 ㄴ 것 없이 완벽 하 ㄴ 갓 겜 이자 너',
#  '나쁘 지 는 않 은데 엔딩 을 꼭 그렇 게 만 하 었 어 야하 었 는지 가 아 의문',
#  '인원 이 이 이 라는 점 이 조금 아쉽 ㄴ 것 빼 고는 다 좋 음 약간 어설프 ㄴ 그래픽 과 쓸데없 는 디테일 들 이 거꾸로 매력 포인트 이 ㅁ',
#  '공략 을 보 아도 어렵 네요 초반 부터 이러 면 후반 에서 는 어떻 ㄹ지 두렵 어서 끝 까지 못 하 겠 습니다',
#  '이제 당신 은 년 의 미국 을 만들 ㄹ 수 있 습니다 물론 건너편 의 중국 이 거대 해진 걸 ㄴ 예 외지 만 요',
#  '어렵 었 지만 이런겜 을 좋아하 ㄴ 터 이 라 넘 나 잼 있 습니다 이러 ㄴ 겜 또 있었 으면 좋 겠 네요',
#  '서버 어디 감 미아 요 엉엉',
#  '처음 시작 하 면 화면 이 회색 이 ㅂ니다 회색 화면 에 돌아다니 어 보 았 는데 산 이랑 들 이랑 나 요 네 여 돌아다니 면서 경치 구경 하 는 게임 이 ㄴ 것 같 은데 일단 추천 누르 ㅂ니다 아직 개발 게임 이 라 그러 ㄴ 것 같 아요 ㅋㅋ 좀더 개발 되 면 해보 아야 겠어 요',
#  '레 디 하 는 법 좀 알리 어 주 어요 ㅠㅠ 제발',
#  '오 이거 쪼 ㅁ 만 더 추가 하 ㄹ 꺼 추가 하 면 재밌 을 듯 은 개뿔 좋 게 쓰 자마자 서버 무한 로 딩',
#  '버그 가 심하 고 게임 이 힘들 ㅂ니다',
#  '기분 좋 게 한글 로 플레이 를 하 어서 즐겁 었 습니다 플레이 마지막 쯤 설마 이 것 으로 끝 이 ㄹ까 이 라는 생각 을 좀 많이 하 게 되 었 는데 정말로 끝나 더군요 볼륨 은 좀 아쉽 지만 전체적 으로 만족 하 었 습니다',
#  '재미 는 있 어서 플레이 하 는데 난데없이 잠수 로 강 퇴 당하 었 다 킁 좆 목질 노 답',
#  '애초 에 게임 을 사 고 깔 아서 할려 이 고 하 는데 실하 어 오류 이 라면 스 어 실행 조차 않 돼 ㅁ',
#  '알 니 아무것 도 않 하 었 는데 무슨 타 사 소프트웨어 썻 다 고 년 정지 야 ㅈ 망 겜',
#  '뭐 이런 허졉한게임 이 난생 첨 으로 이렇 게 조작 이 조잡 하 ㄴ 게임 은 처음',
#  '저 화질 비 하 ㄴ 글 이 ㅂ니다 짧 지 않 은 편 이 ㄴ데 숨 은 그림 찾 기 장면 이 넘 짜증나 아요 웬만 하 면 다른 유명 하 ㄴ 게임 들 을 추천 하 ㅂ니다',
#  '게 속 에러 가 뜨 어서 실행 이 안됨 사양 이 되 는 데 도',
#  '좀 더 해보 아야 알 ㄹ 것 같 아요',
#  '석상 이 안 나오 ㅂ니다',
#  '고인물 이 잔뜩 인건 그렇 다고 치 고 최소한 서버 는 관리 좀 하 어 주 어 나오 ㄴ지 얼마나 지나 었 는데 상대 는 멀쩡 하 게 푱푱 푱 잘만 쌓 는데 나 만 블록 생성 에 초정 도 걸리 ㅁ 무엇 이 지 재 네 는 공장 에서 블록 찍 어 내 고 나 는 수작업 으로 만들 어 내 는 것 도 아니 고',
#  '이 고 리 로 딩 하 는 법 안 알려주 어서 환불 하 ㅂ니다',
#  '옛날 에 하 더 ㄴ 포켓 몬스터 같 은 게임 이 다 엔딩 은 두 개고 재밌 기 는 히 ㄴ 데 이거 만들 ㄴ 새끼 정신세계 가 궁금 하 다',
#  '핵 존나 많 아 투표 기능 은 비활성 화되 있 고 하 지 마 셈',
#  '전작 의 결말 도 굉장히 난해 하 게 끝나 서 찜찜 하 었 는데 그 찜찜 하 ㅁ 을 해소 시키 는 것 이 아니 ㄴ 배가 시키 는 듯하 ㄴ 느낌 결국 또 같 은 적과 같 은 분위기 와 같 은 전투 를 데 자 뷰 처럼 반복 하 는 것 은 절대 사양 하 고 싶 다',
#  '게임 은 재밌 습니다 편이 나오 아서 그렇 지',
#  '아 아 레이싱 게임 은 제가 환불 을 웬만 하 어서 안하 는데 파나텍 에서 포스 피드백 이 전혀 느껴지 지 않 으며 모션 피드백 도 음 네 그냥 사지 마 세요 프레임 도 프레임 돈 까지 덤 으로 주 어도 안 갖 을 게임',
#  '운 빻 ㄹ 망 겜 능지 부족 망 겜 자신 의 운 빨 과 능지 를 테스트 하 ㄹ 수 있 습니다',
#  '시간 플레이 동안 요정 이 한번 도 안 나오 았 다 갓 게임 이 다',
#  '하 이것 을 뭐 라고 하 어야 되 나 그냥 사지 마라',
#  '골수 팬 심 으로써 의 플레이 와 커버 에 도 한계 가 있 는 법 이번 작 은 이미 포기 하 ㄴ 지 오래 지만 곧 나오 는 사 쇼 신작 의 그래픽 을 보 고 다음 늘 ㄴ 기대 하 ㄹ 만하 ㄴ 가치 가 생기 었 습니다 그러 니 하 지 말 고 나오 기 를 기다리 ㄹ 걸 ㅂ니다',
#  '게임 을 잘 만들 어 보 아야 헤 ㄹ 조선 운영 이 얼마나 게임 을 망치 ㄹ 수 있 는지 보여주 는 게임 거기 에 아무리 보 아도 운 영진 이 쪽 바리',
#  '써버 개판',
#  '하 ㄹ 만하 기 는 한데 가사 있 는 노래 는 대부분 중국어 대 만 어고 리듬 게임 이 ㄴ데 굳이 배경 을 번쩍번쩍 화려 하 게 만들 ㄹ 필요 가 있 었 나 싶 음 눈도 아프 고 가시성 도 떨어지 ㅁ',
#  '년도 때 나오 ㄴ 게임 으로 ㄴ 이렇 ㄴ 발상 은 최고 이 ㅂ니다 생존 게임 의 최고 라고 도 생각 되 ㅂ니다 다 만 잦 은 크래쉬 와 버그 는 단점 이 되 고 의 특성 상 레벨 을 올리 려는 욕심 에 불법 프로그램 을 사용 하 는 유저 들 에 감점 이 되 ㅂ니다',
#  '고 렙 과 금 충노 닝겐',
#  '메 에 에에 에에',
#  'ㅈ 같 다',
#  '잡것 들 때문 에 못 해먹 겠 네',
#  '월 탱 보 다 야 블리츠 가 훨씬 훠 어 어 어 어 얼씬 티 어 올리 기 는 빠르 ㄴ데 이것 마저 도 무과 금 이 티 어 가기 에 는 상당히 많 은 시간 이 소요 되 ㅁ',
#  '여기 게임 들 이 다 비슷하 어서 무난 하 게 플레이 하 었 지만 이번 건 스토리 가 별 로 이 었 음',
#  '이 게임 을 통하 어 자신 의 성 정체성 을 알아보 는 좋 은 시간 을 만들 어 보 아요',
#  '비틀',
#  '춥 ㄹ 때 창문 열 고 하 니 현장감 이 느껴지 네요',
#  '한글 화 되 어 스 어 해보 았 는데 내 취향 에 맞 아서 재밌 게 하 었 읍니다',
#  '인형 편 에서 죽 고 귀신 따라다니 면 좋 은 거 규 경 가능',
#  '그냥 구 버전 깔 아서 하 세요 구 버전 맛 을 살리 어야지',
#  '오픈 월드 형식 의 퍼즐 게임 퍼즐 게임 좋아하 는 사람 들 에게 추천 하 ㅁ',
#  '더 많 은 의상 이 필요 하 ㅂ니다',
#  '게임 실행 이 안 되 ㅂ니다 게임 실행 을 클릭 하 면 무 반응 에 스팀 에 는 실행 중 으로 나오 지만 아무런 창도 뜨 지 않 습니다 작업 관리자 에서 서비스 에 들어가 면 가 아 실행 중 이 ㄴ데 시작 은 안되 네요',
#  '우리 의 미래 가 되 지 않 기 를',
#  '아주 훌륭 하 ㄴ 소프트웨어 다 창작 마당 만 빼 고',
#  '무료 퍼즐 게임 이 다 그냥 하 ㄹ 만하 ㄴ 무료 퍼즐 게임',
#  '아주 그냥 개 적 화가 쩔 어 버리 ㅁ',
#  '나 는 많 은 것 을 바라 지 않 는 다 게임 은 재밌 는데 멀미 유발 이 너무 심하 어서 오래 못 앉 아 있 겠 음',
#  '구르 어도 치 어 맞 네 개시 받',
#  '대다수 분 들 이 추천 하 는 게임 이나 나 는 별로 다 화면 은 아름답 지만 만화 같 고 이상 하 게 손맛 이 별로 다 결말 을 보 려고 울 며 겨자 먹 기로 꾸역꾸역 진행 하 여 마지막 을 보 았 다 바이오 쇼크 편도 하다 가 때려치 었 는 데 바이오 쇼크 가 안 맞 는 사람 에게 는 별로 네 요',
#  '라이브러리 에 묻히거 이 라 쿠 소 게',
#  '제품 의 표지 의 돼지 의 얼굴 과 는 달리 인 게임 에서 의 돼지 의 얼굴 은 놀 ㄹ라 우리 만큼 순하 게 생기 었 습니다',
#  '친구 와 함께 하 기에 좋 은 게임 한글 화 걸 고 넘어지 는 사람 이 있 는데 사실 없 어도 다 알아듣 을 정도 는 되 는 편',
#  '여러분 이 언제 스키 를 익스 트림 하 게 타 아 보 겠 습니까',
#  '세모 덕 님 방송 보고 알 았 는데 생각 보다 너무 재미있 고 처크 의 표정 이나 몹들 의 행동 들 이 너무 귀엽 었 더 ㄴ 게임',
#  '정신병',
#  '쓸 고 닦 고 정돈 되 는 것 을 좋아하 ㄴ다면 해보 ㄹ 만 하 지 않 을까요',
#  '알 니 무슨 시 이이 발 조오 ㄴ 나아 게임 을 실행 시키 기 도 전 에 무슨 어류 가 뜨 냐 만원 그 녕 날리 어 먹 었 네',
#  '올해 월 쯤 공식 한글 화 되 ㄴ다 하 네요 한글 패 하 지 만들 시 더 ㄴ 분 블 ㄹ 로그 는 닫히 어 있 고 전 관 짝 으로 들어가 ㅂ니다 ㅠㅠ',
#  '재밌 어 이것 이 재밌 어 이거 재밌 다는 사람 들 넷 마블 틀리 ㄴ 그림 찾 기 해보 셈 진짜 개꿀 잼',
#  '한때 인생 게임 이 었 습니다 금요일 밤 에 시작하 어서 밤새 고 플레이 하 기 도 하 었 고요 그렇지만 르 귄 패 하 지 이후 로 는 도저히 게임 을 하 ㄹ 수 가 어렵 게 되 었 습니다 게임 복잡성 이 너무 올라가 었 고 함대 는 대규모 편성 이나 유지 가 어려워지 고 그래서 게임 을 지우 어 버리 었 네요',
#  '게놈 아프 아 토 사우 르스 마리 부화 시키 는 과학 미션 중이 이 었 는데 게놈 로 아직 완성 도 못하 었 는데 발 굴지 고갈 로 뜨 는 건 무엇 버그 ㅈ 망 겜',
#  '트라 인 시리즈 가 아 너무 재밌 어서 기대 하 었 는데 진심 하지 마세 요 늘 ㄴ 시리즈 중 에 마지막 이 ㄴ데 이거 는 뭐 스토리 가 분 도 안 되 어 스 어 꺠 이 고 진짜 스토리 형편없 음 진심 으로 덜 닦 은 느낌 남 트라 인 시리즈 는 까지 하 세요',
#  '조작 감이 좀 더 부드럽 었 으면 좋 겠 다',
#  '소개 영상 을 보 고 오시 ㄴ 거 다 알 ㅂ니다 근데 그러 ㄹ 일 없 으시 ㄹ 걸 ㅂ니다',
#  '게임 이 너무 불친절 하 ㅁ 게임 적인 허용 으로 넘어가 ㄹ 거 도 안 넘어가 고 튜 토리 얼 과정 에서 뭐 가 문제 이 면 툴팁으 로 알리 어 주 어야지 그러 ㄴ 거 하나 도 없 음 환불 하 ㅁ',
#  '청소 시작 물 쏟 음 메 ㄴ 붕 재개 또 쏟 음 빡 종',
#  '전작 의 명성 에 맞 게 확실히 재밌 는 데 전 보다 더 어려워지 었 음 ㅠㅠ',
#  '재미 는 있 지만 아군 지휘관 을 보 면 프래깅 이 왜 생기 었 는지 알 ㄹ 것 같 다 결국 혼자 서 마리 는 잡 지 않 으면 전선 유지 조차 안되 고 아군 은 보이 지 도 않 는 다 멍청 하 ㄴ 멍청 하 ㄴ 재미있 다 와 아악',
#  'ㅈ ㄴ 쓰 ㄹ 때 업 어여 사지 마 열',
#  '갑자기 겜 실행 이 전혀 안되 ㄴ다 오류 코드 는 이 ㄴ데 시바 뭐 가 문제 이 ㄴ지 진짜 좆 망 겜 수준 은 어디 안 갈 는 듯',
#  '왜 플레이 하면 렉 걸리 지 기술 멋지 ㅂ니다 급습 멋지 ㅂ니다 스토리 ㅁ',
#  '모바일 버전 과 플래시 버전 둘 다 해보 았 음에도 불구하 고 오토 마우스 대체 미 지원 은 욕 처먹 어도 쌈',
#  '이 게임 은 스토리 부터 캐릭터 매 고 모든 것 을 서 든 어택 배 끼 었 다 서 든 어택 이 더 재미 있음 스레 기 겜 노 잼 ㅗ 사지 마 샘 후회 하 ㅁ 환 ㄴ 불 ㄱ ㄱ',
#  '일단 개같애 요 좀 많이 개같애 요 그 니깐 개같애 요 아무튼 개 같 은 거 이 ㅁ',
#  '무료 플레이 이 ㄴ데 한글 이 라고 적히 어 있 는데 한글 플레이 가 안되 네요 개 노 답',
#  '어지럽 어 못하 ㅁ 왜 삿 짓',
#  '한글 지원 좀 하 어 주 어 라 한섭 도 망하 었 는데',
#  '자동차 매니아 에 겐 신 의 축복 같 은 게임',
#  '딱 한마디 만 하 ㄹ게요 이 게임 하 고 시계 보 니 아침 시 ㄷ ㄷ ㄷ 겁나게 재밌 습니다 아 옛날 퀘이크 하 더 ㄴ 시절 도 떠오르 고 울 ㄹ 펜 이나 두 ㅁ 캐릭 트 어도 참전 하 니 개꿀 이 에요',
#  '조작 방법 은 조이 패드 에 맞추 어 지 어 있다 긴하 는데 타격 감이 종이 때리 는 것 보다 못 하 ㅁ',
#  '모드 깔 고 싶 다',
#  '재밌 는데 컨텐츠 가 부족 하 어요 업 뎃 좀',
#  '발전 가능성 이 보이 는 나름 꾸르 잼 게임',
#  '시절 의 방황 하 더 ㄴ 바하 시리즈 분명 재미 는 있 는데 액션 도 공포 도 스토리 도 묘하 게 조금 씩 부족 하 ㅁ 할인 때 구매 하 ㄹ 것 을 추천',
#  '적어도 풀 스크린 이랑 오버레이 지원 그리고 키 설정 은 좀 지원 을 하 어야 하 는 거 아니 ㅂ니까 게임 이 너무 불친절 하 ㅁ',
#  '김 나성 보고 하 지 마라',
#  '중력 시스템 너무 답답 하 어서 못하 겠 습니다',
#  '저 지금 울 고 있 음',
#  '진부 하 ㄴ 러브 스토리 지만 스토리 를 크 게 신경 쓰 지 않 아도 배경 이 재미있 다 신나 ㄴ다 와우 퀴즈 풀 다가 빡 이 치 ㄹ 수 있 으니 힌트 를 보 ㄹ 수 있 는 슈팅 게임 공략 책 을 보 거나 인터넷 을 찾아보 세요',
#  '평가 들 을 보 고 구매 를 해보 았 다 일단 나 는 환불 을 하 었 다 무슨 게임 이 ㄴ지 모르 겠 다',
#  '의외로 노 잼',
#  '왜 내가 괴물 하 면 약 하 ㄴ 거지',
#  '내가 플랫 포 머 류 게임 을 싫어하 는 것 을 알 게 하 어 주 ㄴ 게임 스토리 심오 하 니 뭐 니 포장 들 하지만 그냥 짜임새 있 게 짜 아 놓 은 것 이 아니 라 알려주 ㄴ 것 이 없 으니 자기 들 끼 리 소설 쓰 는 거 뿐 이 ㅁ',
#  '재밌 지만 고인물 난장판 게임 노 답',
#  '블옵 가 아 더 깔끔 하 고 재미있 는 것 같 아요 한글 화 아니 었 으면 걸르 었 을 듯 ㅠㅠ',
#  '이 게임 의 단점 은 조작법 밖에 없 다',
#  '솔직히 이거 난이 도가 씹오 바 개 어렵 어',
#  '게임 이 존망 이 라 그렇 지 은 좋 다 원 레 파 판 시리즈 가 은 다 좋 지',
#  '가 아 ㅈ ㄴ 멍청 하 어서 난이도 최고 로 올리 고 하 어야 되 ㄴ다',
#  '콘솔 로 하면 음성 한국어 이 ㄴ데 로 하 면 무조건 영어 자막 도 없 음 ㄷ ㄷ 영어 에 자신 있 으면 하 시 기 를',
#  '시간 플레이 타임 동안 뛰어다니 는 것 이 시간 이 ㄴ 듯 뜬금 없이 튕기 는 것 은 덤',
#  '도전 과제 달성 도과 때문 에 회 차 극 초반 까지 하 었 는데 나름 괜찮 음 하 지만 달리기 가 없 고 대 쉬 도 딜레이 가 있 어서 약간 의 불편 하 ㅁ 전 투 방식 은 괜찮 음',
#  '전설 의 시작 이 ㅂ니다 꼭 추천 해용',
#  '어렵 다 흑흑',
#  '이 게임 은 멀티 를 지원 하 지 않 습니다 이 게임 은 멀티 를 지원 하 지 않 습니다 이 게임 은 멀티 를 지원 하 지 않 습니다',
#  '알 ㄹ 수 없 는 의 미들 로 가득 차 ㄴ 퍼즐 게임 처음 해보 면 정말 무엇 을 어쩌 라는 것 이 ㄴ지 계속 헤매 게 되 ㄴ다 진짜 아무것 도 알 려 주 는 것 이 없 어서 오랜 시간 을 뻘 짓거리 하 게 만들 ㄴ다 색깔 별로 독특 하 게 꾸미 어 지 ㄴ 맵 디 자 인조 차도 없 었 다면 치 어 다도 안 보 았 을 게임',
#  '를 좀 더 추가 시키 고 튜 토리 얼 도 좀 자세히 만들 어서 초반 플레이 에 도움 되 게 하 어 주 었 음 싶 다',
#  '자동차 의 구조 를 알 기에 매우 적합 하 ㅁ',
#  '분 딱 분만 하 었 는데 벌써 지리 ㄹ 거 같 다 ㅈ ㄴ 무섭 네',
#  '노스 오브 더 워리 어 어 보 단 적지 만 버그 쩔 고 공략 때문 에 골 아프 았 음 주인공 들 도 별로 녀 ㄴ 넘어가 는데 신작 안 나오 는 것 은 이렇 ㄴ 이유 이 ㄴ가',
#  '드 론 때 매 해킹 을 하 ㄹ 수 가 없 네',
#  '진행 중 매치 에 들어가 는 것 좀 없애주세 요 제발',
#  '와우 개꿀 잼 이거 마우스 로 도 조종 이 가능 하 ㅁ 미치 었 음 그리고 꿀 잼',
#  '재미 는 있 는데 고인물 들 이 너무 많 아서 좀 짜증나 네요 ㅎㅎㅎ',
#  '일단 존나 개 적화 이 다 좆같 음 절대로 하 지 마라 사양 낮 은 사람 들 은 비 추천 ㅇ ㅇ',
#  '좋 았 더 ㄴ 점 은 라 라 크로포트 를 다시 만나 ㄹ 수 있 는 거 밖 에 없 고 잔 버그 까 지 는 이해 하 는데 진짜 스토리 개 망 폐기물 수준 쉴드 를 쳐주 ㄹ 수 가 없 음 그냥 쉬 ㄹ 드로 패 고 싶 음',
#  '네트워크 오류 때문 에 멀티 를 못하 네 존나 개 적화 지리 네',
#  '이거 멀 ㄹ 티만 되 었 다면 비슷 하 ㄴ 게임 들 압살 하 ㄹ 수 있 었 다',
#  '비추 천',
#  '전선 확장 및 에너지 관리 를 소재 로 한 게임 서서히 밀리 어 올라가 는 전선 을 보 면서 기뻐하 ㄹ 수 있음',
#  '쒸익쒸 익',
#  '사 아 보삼 후회 는 안 하 ㅁ',
#  '예상 하 ㄴ 그대 로 의 내용 시간 낭비 비추 차라리 짱구 아빠 영상 이 배 는 더 감동적',
#  '재 밋 음 단지 어려움 난이 도 도전 이 두려워지 는',
#  '초 짜리 용 자 판 의 그 느낌 그대로 반드시 픽 세 ㄹ 판 으로 하 ㄹ 것 스팀 판 에 추가 되 ㄴ 그냥 그래픽 모드 로 하 면 재미 가 반의 반의 반도 안됨 아쉽 ㄴ 점 이 라면 판 에 있 더 ㄴ 갤러리 모드 가 사라지 ㅁ 으아 뻐 킹',
#  '개 재 밌었 스 ㅁ 데 헷',
#  '휴대폰 으로 모 모랑 채팅 하 며 임무 를 수행 하 는 인 디 공포 게임 너무 짧 고 단순 하 며 한국어 지원 도 없 습니다 세일 많이 하 ㄹ 때 해보 세요',
#  '겜 시작 하 ㄴ지 분만 애 버그 로 바닥 으로 무한 빨려들 어 감',
#  '게임 이 안되 어 무슨 문제 이 ㄴ지 는 모르 겠 지만 튜터링 이 끝나 고 보 ㄴ 게임 이 들어가 기 전 에 하얀색 로딩으 로 정지 후 안됨',
#  '대충 복수 하 ㄴ다는 내용 인건 알 겠 지만 영어 라서 잘 못 알아먹 겠 다 게다가 남부 사투리 이 다',
#  '아들 아 아 나 는 도대체 이것 이 뭔 개소 린 지 알아먹 지 못하 겠 구나',
#  '층 까지 내려가 었 는데 왜 애 들 머리 수집 하 냐 존나 무섭 게',
#  '가격 의 비하 어서 너무 재밌 다',
#  '유저 한글 화 는 사랑 이 ㅂ니다 스텔스 도 라우드 도 재미있 습니다 다 만 버그 때문 에 좀 헤매 었 더 ㄴ 기억 이 있 네요 난이 돌 는 저 의 기준 에 는 조 오금 있 는 편 이 ㄴ데 조절 이 가능 하 니까 좋 았 습니다',
#  '보더 랜드 시리즈 에 진짜 극도 의 애정 이 있 는 거 아니 ㄴ 이상 건너뛰 어도 무방 하 ㄴ 편 이 ㅁ 그리하 여도 나 에서 언급 이 되 는 보스 가 여기 보스 이 기 도 하 니까 싼값 으로 할인 하 면 사서 해보 는 것 도 나쁘 지 는 않 아요',
#  '짧 게 즐기 기에 는 좋 지만 달성 은 매우 귀찮 음 주차 나 진행 하 기에 는 단순 반복 뿐 이 라 흥미 가 떨어지 ㄴ다',
#  '왜 이것 이 블랙 옵스 이 ㄴ가 아직 도 모르 겠 고 그냥 좀비 겜 되 ㄴ 거 같 음 느 ㄴ 언제나 폭 망',
#  '윈도우으 로 구 동시 처음 화면 에서 깜박거리 ㅁ 이 존재 하 며 게임 안 에서 건물 을 건설 하 ㄹ 시 스크린 샷 처럼 화면 이 렉 이 걸리 는 듯하 ㄴ 상황 이 발생 하 ㅂ니다 다른 지역 에 갔다오 면 그 현상 은 사라지 지만 상당히 거슬리 네요 그 외 에 는 재미있 게 플레이 하 이 었 습니다',
#  '지금 생각 하 어 보 면 왜 사 었 을 까 아 후회 중 워 해머 살 ㄹ 것 을',
#  '이 시리즈 는 안 하 시 어도 되 ㅂ니다 하 는 내내 짜증 과 지루 하 ㅁ 이 가득 하 었 습니다 스토리 도 짜증나 고 계속 등장 하 는 딸 들 은 이야기 를 아주 루즈 하 게 만들 네요 ㅗ',
#  '훌륭 하 ㄴ 협동 게임',
#  '인단 전 은 미국 ㄴ 에서 어ㅣㄱ구 요 인 게인 어 어 더 꺼 ㄴ 한 으지 몬으게서 요',
#  '스팀 출시 하 ㄴ지 얼마나 지나 었 는데 아직 도 멀티 가 제대로 안되 냐 멀티 지향 게임 은 무슨 강제 솔로 잉 게임',
#  '남 주목 소리 졸 ㄹ라 좆 병 신임 하반신 마비 라 제 데로 걷 지 도 못하 ㅁ 한 마디 로 인생 헛살 은 으 바리 색 기',
#  '설정 창 에 서 어 어치 브먼트 플 리 즈 입력 하 면 도전 과제 줌',
#  '전체적 으로 깔끔 하 고 친절 하 며 배경 캐릭터 스토리 전부 마음 에 듣 었 다 하지만 전투 시스템 은 익숙 해지 는데 오랜 시간 이 걸리 었 고 쾌적 하 ㄴ 전투 를 하 기 까지 꽤 오랜 시간 이 걸리 었 다 정통 중 에서 는 손 에 꼽 을 정 도로 완성도 가 높 다',
#  '무 한로 딩 좀 고치 라고 족 같 아서 진짜로 그리 고 왜 계속 빨 ㄹ 핑 만 처 잡히 어 진짜 개 화나 게 문의 도 못 하 고 진짜 짜 ㄴ ㅇ ㄻ ㅈ ㄹ 진짜 니 자 ㅓ릱',
#  '조작 열라 불편 하 ㅁ 그 ㄴ데 플스 패드 는 왜 안 먹 는지 알 는 사람 검색 하 어 보 아도 안 나오 아요',
#  '어떻 게 하 는 것 이 ㄴ지 도 모르 겠 지만 재 밋엇 늘 ㄴ 보여 서 살 는데',
#  '재미 도 없 어 억지로 하 었 지만 시간 이 남 아도 하 지 말하 아야 하 ㄹ 게임 이 ㄴ 거 같 습니다',
#  '옛 게임 의 향수 는 이제 로 느끼 자',
#  '패드 로 하다 가 버그 먹 고 게임 정지 되 길래 냅다 패드 던지 고 환불 하 ㅂ니다',
#  '중병 같 은 대사 잘 버티 면 좋 은 작품 이 ㅂ니다',
#  '목욕 타월 주인공 말 고 금발 드래곤 을 주인공 으로 뒷 내용 드 어 주 세요',
#  '최적화 좆 망',
#  '노 잼 라이브러리 늘리 는 용 입 죠',
#  '엄청나 ㄴ 타격 감 수도 없이 많 은 무기 몇 년 을 기다리 었 는지 모르 ㄴ다 ㅠㅠ 도 만들 어 주 세요',
#  '같이 하 시 ㄹ 분 게임 물리 엔진 좆같 네',
#  '알 니 이렇 ㄴ 경우 가 어딨 냐 진짜 돈 존나 게 뜯 어 가 네 사면 모해 아이디 만들 어 또 들어가 서 아이 핀 만들 어 그 랜 늘 ㄴ데 안되 잖아 모 시스템 을 이따 구로 만들 냐 컴퓨터 잘 몰르 아서 모르 겠 는데 진짜로 빡 치 네',
#  '별 생각 없이 시간 때 우기 용 스토리 를 따라가 면 되 어 는 거기 때문 에 그렇 게 무역 을 열심히 하 ㄹ 필요 가 없 습니다 열심히 하 었 다가 허무 하 게 끝나 ㄴ 케이스 ㅎㅎ 딱 스토리 에 필요 하 ㄴ 만큼 만 얻 고 진행 하 고 하 면 되 ㄹ 거 같 네요',
#  '처음 에 는 재미있 게 플레이 하 었 는데 나중 에 가 니깐 스테이지 구성 도 지루 해지 고 스토리 도 뭔 가 아 크 게 있 을 것 같 다가 허무 하 고 아무튼 나쁘 ㄴ 게임 이 라고 말하 기 는 좀 그렇 지만 사서 하기 에 는 아깝 ㄴ 것 같 아요',
#  '낳 ㄴ 신이 되 면 안되 ㄴ다는 것 을 알려주 는 게임',
#  '다 좋 은데 정말 다 좋 은데 멀 ㄹ 티 플레이 환경 은 최악 중 에 최악 모든 장점 을 뒤엎 을 정도 로 화딱지 가 나 서 비추',
#  '계속 하 어서 하 게 되 는 재미 가 있 다',
#  '죳 쓰레기 코 박스 사 라',
#  '이 게임 은 예전 에 사 었 는데 지금 생각 하 면 왜 만들 어 지 었 는지 의문 이 들 는 게임 이 다 절 때 사지 마라 이것 보다 훨 신 재미있 는 무료 게임 은 널리 고 널리 었 다',
#  '첫 장 전 성공 하 는데 시간 걸 림 생각 보다 익숙 하 어 지면 장전 금방 하 는데 빠요엔 만 안 만나 면 되 ㅁ 글 고 이 겜 악평 하 는 놈 드 ㄹ 이해 가 안되 는 것 이 이 게임 은 원 이 라는 것 을 생각 을 안 하나 원 짜리 로 이정 도 물건 이 면 충분히 잘 만들 어 지 ㄴ 거 아니 ㅁ',
#  '협동 하 며 웨이브 막 는 것 이 재밌 는 게임',
#  '발 이 땋 ㄴ 것 을 돈 받 고 팔 냐',
#  '아프 ㄴ 아프 ㄴ 이 조류 는 인형 뽑 기 기계 이 ㅂ니까',
#  '유일한 불 만이 이 었 으나 로 업데이트',
#  '처음 에 는 배우 는 것 이 좀 혼란 스럽 고 어렵 지만 배우 는 과정 이나 배우 고 나 서 퀄리티 있 는 연설 과 그래픽 신나 는 브금 이 두 두 ㅁ 칫 하 게 하 어 주 ㅂ니다',
#  '여러모로 무리수 를 내 ㄴ 느낌 이 ㅂ니다 이 시리즈 계속 하 어도 되 나 싶 습니다 단간 플레이 하 고 가 있 다구 여기 서 더 이어지 ㄴ다고 하 고 생각 하 었 는데 더 이어지 면 안되 었 습니다 제작사 는 단간 시리즈 제작 을 멈추 어 라',
#  '이거 멀 ㄹ 티 관련 하 어서 로그 인 하 려는 대 왜 이메일 이랑 조합 이 안 맞 다는 문구 가 나오 내요 안 돼 는 것 이 ㄴ가요',
#  '할인 하 길래 사 었 는데 재밌 네요 ㅎㅎ 멍청 하 ㄴ 도 용서 가 되 는 정도',
#  '잠입 플레이 하 기에 는 너무 지루 하 다',
#  '히 오스 다음 갓 겜',
#  '쓰레기 이 란 말 이 여기 에 붙 는 다 이거 깔 을 면 당신 의 하드 디스크 공간 이 부족 해지 ㄴ다 절대 까 아 질 마라',
#  '겜 에 손 이 안 갈 는데요',
#  '싸 게 사 아서 재미있 게 하 었 습니다 근데 해변 늘 ㄴ 다른 맵에 비 하 면 기대 미만 이 네요 그리하 여도 재미있 게 하 었 습니다',
#  '겁 나 아 재 밋 다 이런 어 어 드벤 치 어 액션 게임 을 외 어 이제 알 았 을까',
#  '쓰레기 같 은 게임 모니터 해상도를 지 맘대로 바꾸 어 버리 네',
#  '지금 하 어도 재밌 다 옛날 생각 존나 나 네',
#  '한국 에 오 세요 맥밀런 우리 는 당신 을 기다리 ㅂ니다',
#  '올 오래전 에 사서 받 은 거지 만 지금 에서 야 추천 레이싱 게임 을 잘못하 는 나 에게 도 나름 신선 하 었 더 ㄴ 게임',
#  '스테 파 노 까지 는 좋 았 는데 뭔 사이비 사무엘 잭 슬 ㄴ 나오 ㄴ 후론 개 ㅄ 같 음 크리 치 어도 그닥',
#  '같이 하면 좀 재밌 을 꺼 같 기 는 하지만',
#  '하 자마자 졸리 고 지루 하 어서 껐습닏 낳',
#  '정확히 다 보 는데 분 걸리 었 네요 분기점 이 있 지만 이벤트 씬 차이 일 뿐 이 고 엔딩 이 바뀌 ㄴ다 거나 하 는 건 없 습니다 참고 로 이 게임 을 하 는 이유 는 트레이딩 카드 의 가격 때문 이 ㅂ니다',
#  '내가 리뷰 남기 는 일 이 거의 없 는데 정말 화딱지 가 나 아서 한마디 남 김 대전 액션 게임 에 스틱 지원 이 거지 같 고 대각선 입력 이 안되 는 것 이 말 이 되 냐 오 아 무슨 생각 으로 만들 었 는지 모르 지만 얼른 수정 되 기 를 바람',
#  '금방 엔딩 보 ㄹ 수 있 어서 좋 네요 엔딩 까지 지루 하 지 않 음',
#  '육식 교육 식 교육 식 교육 식 교육 식 교육 식 교육 식 교육 식 교육 식 교',
#  '네 재밌 네요 ㅋ 지우 ㄹ 거 얌 ㅋㅋㅋㅋ',
#  '현질 유도 심 하 ㅁ 그리하 여서 접음',
#  '나 는 게임 을 평가 하 ㄹ 때 감정 에 치우치 지 않 고 이성적 으로 판단 하 려고 노력 하 ㄴ다 하지만 이 게임 은 뭐 랄 까 아 음 그냥 욕 나오 는 게임 이 다 내 가 왜 이 게임 을 돌 ㄴ 주고 사 었 을까 하 는 반성 을 하 며 나 는 오늘 도 갓 겜 히 오스 스킨 을 살 ㄴ다',
#  '엔딩 보고 리뷰 쓰 ㅂ니다 질 ㄴ 엔딩 까지 보 는데 난이도 가 어렵 기 는 하 지만 그만큼 진 엔딩 때 엄청 소름 돋 았 네요 ㅋㅋㅋㅋ 한마디 로 갓 겜',
#  '이 게임 은 하나 의 메세지 를 우리 에게 지속적 으로 주입 시키 ㅂ니다 그거 다 니 손 탓 임 하 지만 분하 게 도 맞 는 말 이 라 분노 를 삭히 ㄴ 채 열심히 미트 보이 를 꼬라박 게 되 ㅂ니다 이렇게 악랄 하 ㄴ 게임 이 ㅂ니다 여러분',
#  '좋 은 게임 이 길 ㄴ 하 ㅂ니다만 매치 밸런싱 이 기존 보다 떨어지 는 느낌 이 라고 하 ㄹ까요',
#  '조작 감 거지 같 다는 비추 들 장애 이 ㄴ가 달리기 하 ㄹ 때 마우스 로 움직이 ㄹ 수 없 는 것 이 익숙 하 지 않 다 거나 설명 이 불친절 하 ㄴ 거 는 인정 하 겠 는데',
#  '이것 이 테크 모 축 구도 아니 고',
#  '서버 문제 만 해결 되 ㄴ다면',
#  '인생 냠냠 게임',
#  '히야 내가 초 나 멈추 ㄹ 수 있 다',
#  '저 는 디 제 잉을 하 고 있 었 습니다 거기 에 는 귀엽 지만 괴상 하 ㄴ 강아지 도 있 었 으며 한참 디 제 잉을 하다 가 막바지 에 가 아서 음악 을 저장 하 는 구간 에서 튕기 었 습니다 끝',
#  '금 게임 의 혁신적 이 ㄴ 나치 죽이 기 게임 섹스 섹스 오 에',
#  '인 디 게임 의 새롭 ㄴ 시대 를 열 게 하 어 주 ㄴ 아이 작의 번제 의 리버스 작품 복불복 의 게임 이 ㄴ 만큼 어렵 면 서도 템 빨 ㄹ 과 컨트롤 로 게임 을 승부 하 ㄴ다 하지만 게임 자체 는 폭력 성 종교성 불쾌감 을 주 ㄹ 수 있 으니 처음 하 는 사람 입장 에서 는 주의 하여 진행 하 어야 하 는 게임 이 ㅂ니다',
#  '훌륭 하 ㅂ니다',
#  '왜 친구 초대 하 면 세 션 만들 ㄴ다고만 나오 고 초대 가 불가능 하 ㄴ 것 이 ㄴ가요',
#  '분명히 오늘 하나 깨 야지 하 고 들어가 었 는데 왜 금방 나오 았 지',
#  '반복 되 ㄴ 늘 ㄴ 중독성 이 이렇 게 재미있 을지 는 모르 았 다 구리 ㄴ 그래픽 그 ㄴ데 이것 도 인 디 계 에서 는 평 타 아 다을 제외 하 고는 흠집 낼 건수 가 없 다 제작자 의 추가 컨텐츠 만 기다리 자',
#  '알 니 시댕 멀티 하 ㄹ 꺼 이 면 하 지 마 셈 랙 오지 어요',
#  'ㄹ ㅇ 로 나오 아 가지 고 골르 았 읍니다 알 니 너무 예쁘자나 여',
#  '구작 히트 맨 과 코 만 도스 를 즐기 어 하 었 더 ㄴ 사람 들 이 라면 분명 즐겁 게 하 ㄹ 수 있 는 탑 뷰 실시간 전략 잠입 게임 이 드디어 돌아오 았 습니다 쉐도 우 택틱스 에서 보여주 었 더 ㄴ 그 기분 을 다시 한번 느끼 어 보 세요',
#  '뭐 야 히 바 나 얼굴 돌려주 어요',
#  '으어컨트롤 은 자신 있 는데 이 같 은 조작 감 으로 는 못 버티 겠 다 하 지만 그래픽 이 너무 귀욤 ㅎ',
#  '시리즈 모두 최고 이 에요',
#  '네 코 오 이라고 하 는 게생겻어 요 그리하 여도 아직 까 아 진 많이 컨텐츠 가 부족 하 ㄴ 게임',
#  '산지 달 됬 늘 ㄴ 데 무료 이벤트 하 네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '걍 튕기 ㅁ 하 지 마 셈',
#  '세이브 안됨 겜 관리자 의 권한 으로 해 도 시발 낳 ㄴ 폴더 왜 안 생기 냐 고 시발람들 아',
#  '던 오브 워 편 편 까지 나오 았 는데 편이 가장 재미 있음 렐릭 은 리 마 만 하 어도 잘 팔리 ㄹ 꺼 같 은데 울 ㄹ 티 메이트 아 아 포 칼 립스 모드 쓰 면 혼자 놀 는 재미 도 쏠쏠 하 ㅁ',
#  '조작법 도 간단 하 고 터트리 는 맛 도 아주 좋 은 게임 이 ㅁ',
#  '대체 자 면서 뭔 짓 을 치 어 하 길래 무기 를 잃어버리 고 자 면서 무엇 을 치 어 먹 길래 중독 에 걸리 는 거 이 냐 생존 게임 을 가장 하 ㄴ 운 을 시험 하 는 좆 망 겜 이 다',
#  '캐릭터 설정 이 구리 고 너무 뜬금없 다',
#  '제목 때문 에 장난 으로 사 었 는데 재미 없었엉',
#  '왜 사람 들이 를 찬양 하 나 하 었 는데 이번 무비 를 보 고 저 도 빠지 어 버리 었 네요 게임 이 로서 높이 평가 받 는 그날 이 빨리 오 았 으면 좋 겠 습니다',
#  '저의 인생 최대 의 실수 중 하나 는 이 게임 을 다운 받 고 플레이 하 었 다는 겁 니 다 ㅎ',
#  '좋 은 아이템 뜨 어 달라 고 바라 는 것 보다 버튼 연타 하 는 것 이 더 빠르 ㅁ',
#  '확실히 로얄 을 만들 면서 삽질 을 하긴 하 었 지만 게임 의 기본 은 좋 기 때문 에 재미있 습니다 저 는 추천 하 겠 습니다',
#  '핵 노 잼 플래쉬 게임 하 지 말자',
#  '철권 이나 소 울 ㄹ 칼 리버 에게 질리 었 다면 추천 솔직히 이것 만 한 격투겜 을 못 보 ㄴ 듯',
#  '졎 망 겜ㅗㅗㅗㅗㅗ',
#  '왜 삼각 빻 ㄴ 쓰 는 없 을까',
#  '실행 도 안되 ㄴ다',
#  '세입자 가 갑 이 다',
#  '시간 내 로 즐기 ㄹ 수 있 는 짧 은 동심',
#  '한글 화 이 라 매 한글 화 이 라 매 아직 번역 이 덜 되 ㄴ 부분 이 상당수 이 ㅂ니다만 네 단점 은 그 것 이 ㅂ니다',
#  '병신 같 은 게임 이 시작 하 자마자 주장 의 은퇴 소식 이 메인 뉴스 전 북 이동국 선수 교체 하 는데 이름 이 다 면 누 가 누 군 데 그러 면 별명 설정 이나 넣 어 주 더 ㄴ가 뭐하 ㄴ다고 프레임 은 죽 어 라고 떨어지 고 그냥 다르 ㄴ 거 하 ㄹ게요 빠셍',
#  '사탄 이 만들 ㄴ 게임',
#  '하 ㄹ 거 겁 나 아 많 음 친구 랑 하면 배가 되 ㅁ 아 아 직 앞서 해보 기 이 ㅁ 계속 할거 많 아 짐',
#  '처음 에 는 갓 겜 이 라고 하 었 는데 개 망 겜 이 네요 액 셀 이랑 설정할려 니 버그 나 서 설정 안 돼 는 ㅈ 망 겜',
#  '개 뻥튀기',
#  '중독성 오지 ㅁ ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '오픈 월드 형 로그 라이크 난이 도 상당 하 ㅁ 맵도 많 고',
#  '플레이 타임 도 꽤 되 는 게임 이 ㄹ 터 이 ㄴ데 힘들 게 깨 고 보 는 엔딩 이 전부 비극 이 란 말 을 듣 고 손 을 때 어 었 다',
#  '맥스 의 뒤돌 려 차기 를 보 ㄴ 적이 있 는가',
#  '뭐 좋 아요 아직 미완성 이 ㄴ 것 을 감안 하 었 을 때 가볍 게 구매 하 어서 기다리 어 보 는 것 도 좋 죠 나중 에 가격 오르 면 배 아프 잖아요',
#  '재미지 어요',
#  '이만 게임 없 는 거 같 다 진짜 갓 겜 업데이트 도 꾸준히 하 어 주고 버그 도 거의 없 고 현실성 이 죽이 는 게임 외국인 유저 랑 하 는 것 도 재밌 고 가끔 한국 유저 도 만나 는데 한국 유저 유입 많이 됬으 이 면 좋 겠 다',
#  '재밌 기 는 함 사 면 후회 는 안하 ㄹ 듯',
#  '윈도우즈 의 기본 지뢰 찾 기 보다 상당히 쉽 ㄴ 편 그러나 처음 하 는 사람 이 라면 어렵 ㄹ 수 도 있 겠 지 그러 ㄴ 사람 들 을 위하 어 준비 하 었 습니다 보상 이 있 는 지뢰 찾 기 지뢰 를 모두 다 찾 는다면 태양 이 썰 ㄴ 글라스 끼 는 것 을 보 는 것 보다 ㄴ 이거 라도 보 는 것 이 더 낫 잖아',
#  '중립 덱 ㅂ ㄷ ㅂ ㄷ',
#  '게임 에서 는 분명 손 을 조종 하 는데 나 는 몸 을 베 베 꼬 고 있 어 지 는 게임',
#  '저기 궁금 하 ㄴ 것 이 있 는데요 왜 키보드 설정 이후 게임 나가 었 다가 다시 실행 하 면 키보드 설정 이 초기화 가 되 는 것 이 죠 어이 가 없 네요 혹시 알 는 분 계시 ㅂ니까',
#  '그래픽 허 접하 고 분하 다 다운 되 ㅁ 내 그래픽 카드 쿼드 로 시리즈 환불 요청 한 상태',
#  '최적화 ㅈ ㄴ 잘 되 어 있 다 ㄷ ㄷ',
#  '이거 해보 니까 재미있 네요 하 ㄹ 만하 어요 추천',
#  '왜 해 시바 하 지 말',
#  '내 겐 ㅈ 망 겜 안 한 다 프 로 피 ㄹ 렙 업 카 아 들 수 집 게 임 이 상 이 하 도 아 아 니 다',
#  '이 게임 하다 실제 로 토 하 었 음 그리하 여서 환불 받 음 비위 멀미 약 하 ㄴ 사람 절대 하 지 마 세요',
#  '에임이 좋아지 ㅁ',
#  '왜 가격 내리 어 갓 냐 만원 때 삿엇 늘 ㄴ 데',
#  '파고들 ㄹ 만하 ㄴ 가능성 은 무궁무진 하 게 보이 지만 굉장히 하드 코어 하 ㄴ 게임 이 다 덜 ㄴ 전 안 에 들어가 자마자 생각 없이 걸어다니 면 가시나 돌덩이 화살 에 맞 고 초 도 안되 어서 뒤지 더라 하드 코 어함 을 견디 지 못하 는 사람 들 한테 느 ㄴ 비추',
#  '로그 인 이 안 되 어 스 어 문의 하 었 더니 동문서답 만 하 는',
#  '뭔 좌회전 이 안되 냐',
#  '물 에 젖 은 섹시하 ㄴ 엉덩이',
#  '문과 가 분 컷 하 었 으니 괜찮 은 성적 이 짓',
#  '게임 자체 는 훌륭 하 다고 생각 하 ㄴ다 닿 ㄴ 한가지 심각 하 ㄴ 문제 가 있 다면 쓰레기 같은에 있다 접속 에 러 가 수시로 뜨 기 때문 에 원활 하 ㄴ 게임 플레이 가 불가능 하 다',
#  '스타터 는 스텐다드 로 업 글 하 어 주 는데 스텐다드 만 아무 혜택 이 없 다 지금 까지 스텐다드 쓰 더 ㄴ 사람 은 흑우 되 는 것 이 ㅂ니까 시간 동안 명성 힘들 게 모으 아서 오퍼 열 고 있 는데 적어도 십 만 명성 은 주 더 ㄴ가 스텐다드 아무 혜택 없 는 거 실화 이 냐 고',
#  '초 딩 들 ㄹ 무 개념 유저 들 극 혀 ㅁ',
#  '정말 사랑 스럽 ㄴ 게임',
#  '귀엽 ㄴ 그래픽 과 훌륭 하 ㄴ 음악',
#  '우주 정어리 내 머리 아프 ㄴ 만들 다 그 러나 이 다 재밌 는 게임 농담 이 ㄴ 거 알 죠',
#  '캐릭터 커스 터 마이 징 요소 도 있 고 무대 위 에서 공연 을 하 ㄴ다는 주제 자체 는 매우 신선 하 고 재밌 으나 레이 시스트 랑 성차별 하 는 사람 간간히 보이 기 때문 에 나 같이 메 ㄴ 탈 이 좋 지 않 은 아시안 여자 는 사 지 않 는 것 을 추천 하 ㅁ',
#  '재밌 게 즐기 다 진행 상황 이 초토화되 는 경험 을 해보 면 깨닫 겠 지 스바 ㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏ 알 이 라고',
#  '번창 하 세요',
#  '쓰레기통',
#  '사람 도 없 고 그래픽 도 동영상 처럼 은 안 보임 그렇 다고 게임 이 미치 ㄴ 듯이 재밌 는 것 도 아 님 적당히 업데이트 를 기다리 려 해도 업데이트 가 안되 고 있음 제작사 가 버리 었 나 보 ㅁ 안하 시 는걸 추천 만원 너무 비싸 ㅁ',
#  '제발 잘생기 ㄴ 남자 공략 캐릭터 를 만들 어 주 세요 다 좋 은데 못생기 ㄴ 남자 캐릭터 가 넘치 어서 일부러 외면 하 어도 자꾸 마주치 어요 잘생기 ㄴ 남자 공략 가능 하 ㄴ 캐릭터 많이 만들 어 주 세요',
#  '엄청 재미 있음 편도 재미있 었 지만 버그 때문 에 실행 이 안 되 더 ㄴ 데 편 은 잘 되 ㅁ 타워 수비 게임 좋아하 는 사람 은 잘 맞 을 듯',
#  '조작 ㅈ ㄴ 심 하 ㅁ ㅋㅋ 절대 비추',
#  '그래픽 좆같 네요 그냥 하 ㄹ래요',
#  '턴 제 게임 잘 안 맞 는 편 이 ㄴ데 도 재밌 게 즐기 ㄴ 턴 제 게임 스토리 는 별로 매력 없다 고 느끼 었 지만 요소 가 잘 만들 어 지 었 음',
#  '사지 말 아라 뭐 가 변하 ㄴ 것 이 ㄴ지 도 모르 고 밸런스 망',
#  '나 가 왜 이것 을 사 었 는지 후회 가 되 ㅁ니다',
#  '아 아 환불 왜 안하 어 주 어 ㅠㅠ',
#  '유일 하 게 워 해머 시리즈 중 에 엔딩 안본 게임 이 다 개 노 잼 반복 구타 게임 반격 이나 방어 같 은 좀더 전투 에 세세 하 ㄴ 부분 을 넣 기 를 원하 었 는데 나의 스페이스 마린 을 모욕 하 었 다',
#  '오 아 가 아 잘 조합 되 ㄴ 명작 게임',
#  '각 나라 의 인성 을 엿보 ㄹ 수 있 어서 좋 았 습니다',
#  '갯가 제 하 는데 이 ㄴ 칭 시점 움직이 는 것 이 레 알 무슨 저세상 이 네 ㅡㅡ',
#  '내 취향 은 아니 네',
#  '노 잼 완전 재미 없 음 종이 짝 레이싱',
#  '오 엄청 재밌 어요',
#  '그 렉 개 쩜 ㅇ ㅋ',
#  '한글 패치 에 대하 어 불만 이 있 는 이유 는 정식 발매 이 라는 타이틀 로 소비자 를 우롱 하 었 다는 점 과 일본 의 정식 발매 일정 에 한글 패 치르 ㄹ 내놓 겠 다는 개발 사 의 처사 에 있음 을 알 기 바라 ㄴ다',
#  '끝판 대장 레 알 ㄹ 진심 개 사기 보스 이거 만들 ㄴ 제작진 은 직접 오 아서 니들 이 해보 아 라 깨 면 내가 니들 후원 하 ㄴ다 이 망하 ㄹ 놈 들 아 아 게임 은 재미있습니다브금 도 좋 구요 두 번 하세 요 알 니 세 번하 세요',
#  '더럽 게 어렵 네 중요 하 ㄴ 것 은 적이 밀리 어 나오 는 것 이 많 기 때문 에 실력 그딴 거 다 좆까 고 하 어야 하 기에 오 아 진심 슬 나 이 푸 어 라이플 아니 였 으면 하 ㄹ 말 없었 겠 다 기관총 은 왜 안 나오 니',
#  '버그 가 많이 일어나 고 심 하 ㄹ 경우 에 는 엔딩 보 ㄹ 준비 하 고 있 었 는데 데이터 가 삭제 되 어 버리 었 네요 그것 도 번 이나 저 는 이 게임 을 다시 는 하 고 싶 지 않 습니다',
#  '재밌 는데 멀티 에 사람 이 읍 네요 같이 하 면 꿀 잼 이 ㄹ 거 같 은데 그 맛 을 못 보 고 있 음 ㅠㅠ',
#  '그냥 해보 셈 진짜 개 병신 같 은 게임 임 분하 고 지우 ㅁ',
#  '아 아 심플 부터 깨 기 싫 다고 니 마음 만 잇 냐 고 내 마음 도 잇 다고',
#  '차라리 포 나라 하 러 가 라 뭐 무료 이 ㄴ데 괜찮 다 무료 배 고 다 하 는데 어 어 짜 아 피 매칭 이 아예 안 잡히 ㅁ 같 은 무료 배틀 ㄹ 로얄 인 포트 나이트 나 하 러 가 라 포 나',
#  '진짜 머리 굴리 면서 게임 하 어야 되 는 게임',
#  '개조 음',
#  '이 게임 을 시작 하 ㄴ 지 는 얼마 되 지 는 않 았 지만 정말 재미있 게 하 ㄹ 수 있 는 게임 이 ㅂ니다 친구 들 과 함께 하 는데 정말 재미있 습니다 한국 에서 만들 ㄴ 게임 이 라는 것 이 믿기 어 지지 가 않 네요',
#  '자유도 가 높 아 재미있 다',
#  '리듬감 있 고 어렵 어서 재밌 어요 추천 드리 ㅂ니다 부스트 팩 에 도 재밌 는 요소 가 있 어요',
#  '분위기 에 압도 되 ㄴ다 미지 의 세계 를 탐험 하 는 기분',
#  '게임 진행 미연 시과 음악 그래픽 은 나름 인상적 이 지만 그 게 전부 다 스토리 설정 은 좋 은 반면 연출 이나 서술 방식 이 좋 아 보이 지 가 아 않 다 산만 하 고 밑 밑 하 어서 다소 지루 하 게 느껴지 ㄴ다',
#  '주의 이 게임 은 상당히 마 니 악 하 ㅂ니다 가볍 게 플레이 하 려고 하 었 다가 결국 구 글 링 까지 하 게 되 었 습니다 연구 하 는 거 좋아하 시 는 분 들 에게 강추',
#  '이것 도 짱 깨 가 점령 하 ㅁ',
#  '이 게임 은 추억 을 더럽히 ㄴ 게임 이 다 어떻 게 되 ㄴ 게임 이 옛날 보다 더 퇴 하해 버리 ㄴ 거지 옛날 에 그때 그대로 나오 고 그래픽 만 추가적 으로 계속 하 어서 상향 시키 었 으면 오히려 좋 았 겠 다 추억 을 되살리 려고 건들이 었 다가 추억 을 더럽히 게 만들 ㄴ 레드 덕 에게 엿 을 날리 어 주 고 싶 다',
#  '좆',
#  '믿 으라 기도 하 라 복종 하 라',
#  '진심 으로 꿀 잼',
#  '재미없 다',
#  '베데 스 다 식 엔딩 의 시초',
#  '아우 엑 박 패드 인식도 이상 하 고 키보드 입력 도 이상 하 ㅁ 게임 을 하 ㄹ 수 가 없 네 아우',
#  '하 다가 정신병자 되 ㄹ 거 같 다 이 고 퀄 라 보 면 되 ㄴ다',
#  '이 겜 을 시간 한 내가 레 전 드 다',
#  '순 하 ㄴ 맛 돈 스타 블 게임 짱 재 밋 엇 어 욥 친구 랑 넘 재 밋 것 이 함',
#  '솔 찍 히 이것 이 유명 하 ㄴ 시리즈 이 었 는지 도 모르 았 고 걍 꼴리 어서 사 었 다 그래픽 은 나름 준수 하 ㄴ 편 그런데 길 이 너무 불친절 하 ㅁ 초반 에 길 어 어 디 ㄴ지 몰르 아서 지우 었 다 언어 의 장벽 도 한몫 하 ㅁ 지금 은 한글 패 하 지 가 있 는지 모르 겠 지만',
#  '깔끔 하 고 그냥 분위기 를 즐기 기에 도 나쁘 지 않 아 추천',
#  '분명 게임 은 잘 만들 었 지만 컨텐츠 부제 로 하 ㄹ 것 이 없 다 그냥 보이 면 쏘 고 못 보 면 죽 는 죽창 게임 이 이 이 다 전 작 에 선 탱크 기갑 과 여러 기습 루트 가 있 었 지만 이번 작 에서 는 헬기 조종 수가 내리 어 주 는 대 서 내리 고 또 꼬라박 으면 죽 는 지루 하 기 짝 이 없 는 게임 이 되 어 버렷 닿',
#  '덕분 에 글옵 프레임 올르 았 다',
#  '정말 초 갓 겜 코코넛 이랑 돌 만 있 으면 엔딩 오 아 진짜 재미있 다',
#  '동방 캐릭터 들 의 특징 을 잘 살리 어서 만들 었 다는 것 이 제일 좋 네요',
#  '스토리 하나 는 끝내주 ㄴ다고 하 는데 그것 도 사실 개 뻥 이 ㅂ니다 속 아 아서 다 깨놓 고 후회 하 었 습니다 눈 만 존나 게 아프 고 하다 가 너무 졸리 어서 힘들 었 습니다',
#  '원래 영화 보 면서 왜 그딴 짓거리 를 한냐 고 생각 하 ㄹ 때 가 있 는데 이 건 그러 ㄴ 시스템 을 자신 의 선택 으로 옮기 어 주 었 습니다 스토리 가 약간 그리하 여도 선택 시스템 으로 단점 은 거의 없 다 보시 면 되 ㅂ니다',
#  '친구 없 으면 사지 마라',
#  '최적화 좀 많이 하 어 주 었 음 좋 겠 고 가격 이 너무 비싸 ㄴ 감 이 있 습니다 갑자기 만원 껑충 하 어서 팔 는 건 무엇 이 ㄴ지',
#  '일 무료 라 방 들어가 자마자 추방 투표 하 는 짱 깨들 헤 ㄹ 방 에서 렙 이 들어오 는 마술 플래시 파운드 를 화염 방사기 로 지지 는 게임 키 ㄹ 링 플로어',
#  '솔직히 전투 하 려고 이 겜 을 사 ㄴ다면 비 추천 퀘스트 가 너무 불친절 하 ㅁ 그냥 크리 에 이티브 에서 치 ㄴ 구들 이랑 건축 하 고 놀 ㄹ 거 이 면 추천 가격 값 을 하 는지 는 모르 겠 다',
#  '아무 생각 없이 하 기 좋 은 슈팅 게임 초반 이 꽤나 고되 ㄴ 구간 이 있 고 장애물 에 닿 으면 바로 터지 는 버그 가 있 지만 시간 떼 우기 에 는 좋 습니다 음악 도 좋 은 음악 이 많 습니다',
#  '추리 도 너무 어렵 지 않 고 재밌 음 속 편 나오 ㄹ 거 같 은데 그거 도 하 ㄹ 의향 있음',
#  '정말 신 박한 게임 올해 듣 어서 이렇 게 창의 적인 게임 은 처음 이 ㄴ 듯',
#  '퍼즐 게임 특단 순 하 게 생각 하 면 쉽 ㄴ데 단순 하 게 생각 을 못하 ㅁ',
#  '한글 화 퀼리티 가 좀 많이 별로 다 오 타가 나오 는 거 보 면 단순히 번역기 로 돌리 ㄴ 건 아니 ㄴ 거 같 은데 추후 에 수정 되 기 를 기대 하 ㅁ',
#  '멀티 하 면 재밌 는데 멀티 가 안 잡히 ㅁ 그리고 옛날 게임 이 라 조작 감 이 너무 안 좋 음',
#  '저격 이 뭔 가 아 묘하 게 불편 하 고 스토리 는 지루 하 었 다 재미 는 그다지',
#  '어렵 게 생각 하 지 말 고 월 오 쉽 을 하세 요 제발',
#  '크 게 차이 를 못 느끼 어서 아쉽 기 는 한데 그리하 여도 재미 짐 토치 라이트 늘 ㄴ 나오 려는 지 어떻 ㄹ 런지',
#  '전채 적 으로 퀠리티 랑 시스템 이랑 뭐 기타 등등 다 좋 은데 계급 별로 매칭 하 어 주 었 으면 하 는 게임 이 게임 하 자마자 암 치료 하 러 오 았 는데 도 려 암 걸리 는 느낌 아직 오픈 배 타 니깐 기대치 는 높 지만 만약 계급 매칭 안 하 ㄴ다면 기대 조차 하 ㄹ 수 없 는 게임',
#  '몸 팔 는 내용 은 용납 못하 겠 다',
#  '굿 굿 게임 참 재밌 네 여 스토리 보 는 재미 로 하 고 있 습니다 즐기 고 있 습니다',
#  '그냥 의미 도 없 고 아무것 도 없이 쏘 아 죽이 고 끝 노 잼',
#  '시간 은 잘 갈 는데 경험 치가 너무 울 ㄴ 빨 이 네요 친구 없 으면 노 잼 이 ㅁ',
#  '망 겜 같이 하 는 친구 들 한테 까 지 사 라고 하면 서 같이 하 기 는 좀 그럼 사 면 재미 는 있 겠 는데',
#  '포탈 생각 하 고 사 면 후회 하 ㅁ ㅠㅠ',
#  '너무 렉 이 심하 ㅂ니다 게임 을 하 ㄹ 수 가 없 네요 예전 에 재미있 게 하 었 었 는데',
#  '이 건 게임 이 아니 다 대부분 의 시간 동안 당신 은 쓸데없 는 컷 씬 을 감상 하 거나 가끔 ㅈ 같 은 를 하 ㄹ 뿐 이 다 이 돈 이 면 그냥 극장 에 가 아서 영화 를 보 는 것 이 낫 다',
#  '싱글 이 ㄴ데 서버 렉 이 있 어',
#  '초반 좆같 은 게임',
#  '핵 쓰 ㄴ 적 없 는데 감시 부대 밴 당하 었 다 시발',
#  '쩔',
#  '비 추천 그래픽 만 좋 지 정작 구현 되 ㄴ 것 듣 은 별거 없 다 비행기 들 팩 션 당 개 밖에 없 고 배 들 도 간단 하 게 급 별로 종류 씩 만 구현 다른 간단 하 ㄴ 아케이드 형식 슈팅 게임 처럼 맞추 고 피하 면 끝 은 단순 하 ㄴ 게임 대학생 들 의 포트폴리오 수준 이 다',
#  '안녕 내 이름 은 네 가 아 이 글 을 읽 을 떄 쯤 이 면 이미 나 는 죽 었 을 그 어야',
#  '케이브 슈팅 급 대작 전 작인 보 다 잔반 적 이 ㄴ 난이 도 좀 올라가 었 음',
#  '시작 부터 로그 인 에러 뜨 네',
#  '오류',
#  '이런 인생겜 이 없 다',
#  '한글 지원 엔딩 히로인 별 개 씩 개 배 드 엔딩 하렘 엔딩 공 홈 에 있음 플레이 타임 시간 보이스 주인공 제외 전부 비고 스토리 살짝 늘어지 ㅁ',
#  '스트라이크 를 생각나 게 하 는 게임',
#  '각 템 드 ㄹ 의 조합 으로 변수 가 많이 생기 어서 재밌 음',
#  '한번 해보 ㄹ 만 하 고 미래 가 기대 되 는 게임',
#  '패치 하 ㄹ 때 마다 또는 가 아 나오 ㄹ 때 마다 플레이어 들 이 이번 에 는 갓 겜 되 었 다 이번 에 는 갓 겜 되 었 다 하 는 그 겜 이 ㅂ니다 디아블로 가 아 생각나 는군요',
#  '굉장히 재미있 게 즐기 었 더 ㄴ 보다 더 재미있 다 다음 작품 이 ㄴ 은 망 작',
#  '일 만 에 시간 이나 하 었 을 만큼 컨텐츠 도 많이 있 고 갓 겜 이 ㅂ니다 한번 사 면 후회 는 없 음',
#  '섬 의 궤적 이 로 완벽 하 게 이식 되 어 나오 았 습니다 더 이상 의 설명 은 불필요',
#  '배배 컴 형님 미안 하다 이 모든 것 이 나 의 불찰 이 다 사과 를 받 았 으니 돌아가 하하하 멍 청아 내가 무릎 을 꿇 은 것 은 배 필를 만들 ㄹ 추진력 을 얻 기 위하 ㅁ 잇 었 다 배 배필 형님 미안 하다 이 모든 것 이 나 의 불찰',
#  '같 은 그래픽 보고 토 나오 ㄴ다는 말 을 이 게임 보고 하 는 거 이 다 이거 한시간 하 고 토하 었 어 ㄹ ㅇ 로 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '버그 땜 에 스토리 진행 을 못하 잖아',
#  '아씨 부 랄 ㅡㅡ 멀티 를 돈 주고 판다',
#  '존나 무섭 어서 바로 삭제 하 ㅁ',
#  '심심 하 ㄹ 때 이거 하 고 있 으면 시간 잘 감 단점 은 중간 세이브 같 은 것 이 없 어서 끄 었 다 키 면 첨 부터 다시 맞추 어야 되 ㅁ 그리하 여서 한판 시작 하 면 끝 을 보 ㄴ다는 각오 로 하 어야 되 기 때문 에 매우 피곤 하 ㅁ',
#  '아부지 가 누구 시 이 냐 이쓰끼 야 문어 이 ㅂ니다',
#  '나 가 원하 었 더 ㄴ 우주 건설 시뮬레이션 을 충족 시키 어 주 ㄴ 게임 단점 게임 이 너무 쉽 다 도 쉽 었 다 날 더 하드 하 게 괴롭히 어 주 어',
#  '추천 하 고 싶 지 않 다 많이 아쉽 ㄴ 게임 이 다',
#  '애 ㅡㅡ 미디 진거 같이 팅 길 ㄴ다 ㅡㅡ 것 이 롤트 사가 하 느라 펴 ㄴ 억지 로 처하 는데 샷 건 진짜 오지 게 치 ㄴ 듯 진짜 여자 카드 모으 는 거 없엇으 이 면 게임 이 라 칭하 ㄹ 수 도 없 을 듯',
#  '멋지 ㄹ 수 도 있 었 더 ㄴ 워 해머 이야기 아깝 게 낭비 되 ㄴ 인 물들 ㄹ 누 가 우리 의 전쟁 을 심심 하 ㄴ 케이크 장식 따위 로 바꾸 어 놓 았 단 말 이 ㄴ가',
#  '계속 튕기 ㅁ 녀 ㄴ 세이브 못하 어서 접음 뭐 이러 냐',
#  '특이 한데 조작 감 이 심히 어별 로 에 요 익숙 해지 기 힘들 어요',
#  '귀엽 ㄴ 캐릭터 가 여러분 을 반기 ㄹ 것 이 ㅂ니다 상식 퀴즈 한 판 에 세 문제 아 아 이렇 ㄴ 것 이 있 구나 하 는 정도 외국 쪽 은 내가 모르 는 것 이 많 은 것 도 있 기 는 한데 상식 쌓 기에 는 살짝 애매 하 ㄴ',
#  '당최 뭐 가 무엇 이 ㄴ지 모르 겠 는 게임',
#  '스토리 진행 방향 이나 캐릭터 육성 등등 게임 의 요소 가 너무 다양 하 어서 다회 차로 플레이 하 어도 전혀 질리 지 않 아요 정가 로 구매 하 어도 전혀 아깝 지 않 은 게임 이 ㅂ니다 왜 아직 도 사 고 있 지 않 느냐 이 말 이야 회 차 플레이 후 주위 사람 들 꼬드기 는 중 같이 멀티 하 자 굴',
#  '죄송 하 ㄴ데 이거 마스터 리그 랑 비 컴 어 어 레 전 드 모드 가 안 되 ㅂ니다 이 모드 를 하 려면 어떻 게 하 어야 하 나요 참고 로 저 는 무료 로 다운로드 를 하 었 습니다',
#  '우연히 할인 을 하 어서 한번 해보 았 는데 오 아 이 건 정말 재밌 다',
#  '귀엽 ㄴ 그림 체 와 다르 게 뭔 가 미스 테리 하 ㄴ 분위기 의 게임 으로 스토리 도 체계 가 있 고 퍼즐 을 푸 는 데 그리 어려움 이 없 다 다만 수집 하 ㄴ 아이템 에 한해 서 분기점 이 나누 어 지 기 때문 에 꼼꼼히 살펴보 는 습관 을 들이 는 것 이 좋 을 듯하 다',
#  '도전 과제 를 목표 로 느긋 하 게 하 기 좋 은 게임',
#  '왜 한국어 가 없 는 거 야 속 았 다 한국어 지원 이 라 하 었 는데 없 다',
#  '마인 크래프트 막 나오 았 을 때 덤 으로 나오 ㄴ 짭겜 이 ㄴ데 첨 에 베타 이 ㄴ가 하 ㄹ 때 에는 잘나가 었 다가 지금 접속 하 면 온라인 서버 도 거의 없 고 사람 도 없 음 걍 겜자체 가 죽 은 듯',
#  '게임 에서 나의 쥐 를 찾 을 수 없 는 화면 의 움직임 또한 경직 상대 를 헐뜯 는 겨루기 상대 를 찾 을 수 없 어 경로 를 재 탐색 명이 스 어 죽이 ㅁ 을 이루 지 못하 ㅁ 마치 왼쪽 명 죽음 보 다 못하 ㄴ',
#  '이제 과거 로 가보 ㅂ시다 좋 아 이제 돌아가 자',
#  '개 꿀 잼 이 ㄴ데 서버 없 어서 못하 ㅂ니다 치 ㄴ 구들 끼리 하 ㄹ 수 있 으면 꼭 해보 세요',
#  '남 한테 돈지랄 하 ㄴ 거 자랑 하 기 좋아하 면 사셈',
#  '아 아 짜증나',
#  '제발 한글 화안 시키 어도 좋 으니깐 내노 아 공용 화기 내놓 으면 더 고맙 고',
#  '해보 면 암',
#  '음 ㅎ 갠잖아 요 이거 그냥 좀 음 흐 으 음 ㅎ 좀 느리 ㄴ 것 같 기 도 하 고 진행 속도 가',
#  '시 이이 이 이발 카 아 솟 다 망 하 였 어',
#  '쯔꾸 르 류 게임 중 에 드물 게 유치 하다 이 고 느껴지 는 구석 이 한군데 도 없 었 습니다 전체적 이 ㄴ 스토리 와 결말 까지 모두 다 마음 에 들 고 난이도 도 적절 하 였 더 ㄴ 것 같 습니다',
#  '초반 에 알 아 갈 는 과정 만 재밌 음 창의력 종범 이 라 씹노 잼',
#  '뭐 이 냐 이 건 게임 커뮤니티 겜 덕 인원 모 집중 이 ㅂ니다 다른 사람 들 과 인연 을 만들 고 같이 게임 하 고 싶 으시 ㄴ 분 들 연락 주세 요',
#  '리듬 겜 못하 는 분 들 은 어렵 ㄹ 수 도 있 는데 처음 해보 는 저 도 금방 깻 슬 ㅂ니다 정말 추천 하 ㅂ니다',
#  '남 주변 신 스킵 하 고 히로인 변신 하 는 영상 나오 ㄹ 때 크래쉬나 서 꺼지 는데 나 만 그렇 ㄴ가',
#  '재미 는 있 는데 소리 가 잘 안 들리 거나 움직임 이 명확 하 지 않 아서 헷갈리 ㅁ',
#  '제 에 발 핑 좀',
#  '이 게임 환불 취소 요',
#  '자막 하 ㄴ 글 로 부탁 드리 ㅂ니다',
#  '서브 노티 카 마렵 게 하 네 이런 장르 좋아하 ㅁ 못 만들 ㄴ 것 같 지 도 않 음 그 ㄴ데 평화 롭 ㄴ 거 썩 좋아하 지 않 음 졸리 어 디지 ㅁ 스 ㄹ라 임 런 처 스타 듀 같 은 것 들이 고 예 반대 는 갓 갓 서브 노티 카 나 산미 취향 나랑 비슷 하 ㄴ 거 같 다면 참고 하 셈',
#  '그리하 여 다 좋 다고 생각 하 자 실제로 다 좋 다 근데 티 그 어 사거리 가 판 터 보다 안 나오 는 것 과 원거리 포격 이 탄약 들 는 것 은 너무 좋 지 못하 다',
#  '나오 ㄴ 지 얼마 안 됬 늘 ㄴ 데 멀티 가 안 잡히 ㅁ 한 달 내 사람 종 범일 듯',
#  '웹 버전 은 실행 시키 기 귀찮 았 는데 없이 바로 되 니 좋 네요 잠깐 해보 았 는데 영상 도 많 고 삼국지 스토리 를 잘 살리 ㄴ 게임 이 네요',
#  '울 ㄹ 티 사 었 는데 섭종이라 니 잘 만들 었 는데 운영 이 병신 이 라 망 하 ㄴ 케이스',
#  '저 의 프 저 의 프 저 의 프',
#  '어느 카테고리 를 가 더라도 애 니 캐릭터 가 나오 ㄴ다 알 니 메 라 이 고 적히 ㄴ 카테고리 가 분명히 있 지만 네다씹들 은 개의 하 지 않 는 듯 하다',
#  '이 세상 게임 이 아니 다',
#  '내부 에서 지원 하 는 영상 캡 처 툴 은 낮 은 사양 의 컴퓨터 에서 오버 워 치 하이라이트 촬영 을 지원 하 지 않 는데 이 프로그램 덕분 에 깔끔 하 게 찍 을 수 있 었 네요 ㅎ 찍 으면서 컴퓨터 부담 도 적 은 편 이 고 영상 의 퀼리티 도 높 아요',
#  '계속 즐 기기 에 는 너무 구리 어',
#  '게임 자체 는 굉장히 재미있 습니다 하지만 화면 이 너무 번쩍번쩍 거리 어서 눈 이 아프 아 도저히 게임 을 못하 겠 음',
#  '정말로 ㅈ 같 습니다 시 벌 ㄹ 것',
#  '이거 하 ㄹ 바 에 에이스 오브 스페이드 하 는 것 이 낫 겠 다',
#  '장점 전작 보다 ㄴ 재미있 다 단점 그렇 다고 돈 주 고 하 ㄹ 만하 ㄴ 게임 은 아니 다 난잡 하 ㄴ 조작 과 뚜벅 이의 지루 하 ㄴ 매 이동이 특징 이 라 드 ㄹ 수 있 다',
#  '옛날 주 타이 쿠 ㄴ 하 ㄹ 때 감성 이 제대 로 담기 어 있음 너무 좋 아요',
#  '엿 먹 어라 워 게이',
#  '코드 를 받 으라 고 하 는데 코드 가 않 오 ㅂ니다',
#  '한글 화 안되 어 있 고 겁나 게 잘 튕기 고 안 하 ㅁ',
#  '생각 이상 으로 갓 겜 이 었 다',
#  '부정적 이 ㄴ 평가 가 많 은 것 같 은데 그러 ㄹ 만도 하다 는 생각 이 들 ㄴ다 하지만 무료 게임 의 특성 상 더군다나 아직 미치 어 완성 되 지 도 않 은 게임 이 ㄴ데 그 이상 무엇 을 더 바라 겠 는가 정말 하 ㄹ 게임 이 없 거나 도전 과제 수집 이 취미 이 ㄴ 분 들 은 한번 해보 고 지우 어도 무방 하 다',
#  '비싸 게 사 었 는데 원 에 팔 고 앉 아 있 네 시 불',
#  '솔직히 기대 에 못 미치 ㄴ다 모 굴 에 비하 면 데이터 상세 하 ㄴ데 매치 엔진 좋 다고 말 못하 겠 다 병살 코스 이 ㄴ데 도 버벅대 고 버벅대 서 한 베이스 진루 더 허용 하 ㄴ다',
#  '길치 라서 겜 을 못하 겠 음 귀엽 기 는 해',
#  '최고 의 게임 이 다',
#  '어 어 머 이건 꼭 하 어야 대',
#  '답답 하 ㄴ 조작 감 막히 어서 다시 돌아가 아야 하 는 길 이 한둘 이 아니 ㅁ 그 ㄴ데 그 길 에 몹이 맵 을 이동 하 ㄹ 때 마다 리 젠 되 ㅁ 쓰잘데기없 이 길 ㄴ 동선 캐릭터 나 디자인 측면 에서 는 나쁘 지 않 지만 정말 제목 값 하 는 게임',
#  '멀티 서비스 종료',
#  '게임 은 재미있 지만 들 이 잘하 어서 좀 어렵 더군요',
#  '재미있 습니다 의 마지막 확장 팩 이 라는 것 이 죠 에 비해선 밸런스 가 어느 정도 잡히 어 지 었 기 는 하 ㅂ니다 에 비해선 알 니 자만 말 이 죠',
#  '날 잡고 하기 에 는 좀 그렇 고 하루 에 몇 판 정도 하면 오래 즐기 ㄹ 수 있 을 거 같 음',
#  '이 게임 컨셉 잡고 마이크 하면서 게임 하 면 꿀 잼 이 에요 ㅋㅋㅋㅋ 메 소드 연기 로 뱃사람 이 되 ㅂ시다',
#  '근데 이거 다음 챕터 있 는 거 이 ㅁ',
#  '히 오스 매칭 잡 으면서 하 기 딱 좋 은 게임',
#  '무섭 다',
#  '알 니 왜 시발 예전 에 플레이 하 었 더 ㄴ 것 이 저장 이 안되 냐 맨날 다시 하 어야 되 네 지 기렇 ㄹ 거',
#  '깨 ㄹ 뜻 못 깨 ㄹ 뜻 조금 빡칠려 하 ㄹ 때 스테이지 패스 가능 기본적 으로 난이 도 있 는 게임 이 라고 생각 세련 되 ㄴ 음악 여자 목 소리 섹시',
#  '슬 나 가 존나 역겹 다 개 시발 팔 처 맞 아도 뒤지 ㄴ다 특히 서버 가 병신 이 다 과 금 요소 가 매우 조선 스럽 다 커스 터 마이 징 폭 을 넓히 어 주 었 으면 좋 겠 다 게임 은 콜옵 과 매우 비슷 하 다',
#  '만원 짜리 ㅇ ㄷ',
#  '개 쩔 는 전략 을 새우 어 두 고 모든 것 이 ㅈ 되 는 것 을 지켜보 는 겜',
#  '걍 글 픽 테스트 용 게임',
#  '까 ㅁ 노 ㄹ 까 ㅁ 노 ㄹ 하 ㅂ니다 미 러스 엣지 에서 이름 한 번 날리 고 오시 ㄴ 분 도 함께 하 는 게임 추천 하 ㅂ니다',
#  '아름답 ㄴ 음악 과 감각적 이 ㄴ 그래픽 이 매우 좋 았 음 전투 가 반 턴 제 라고 많이 그러 는데 스킬 쓰 고 도망 다니 다가 쿠 ㄹ 되 면 스킬 쓰 고 식 이 라 좀 이상 하다 이 고 느끼 었 음 그리하 여도 음악 하 고 디자인 이 모든 걸 커버 치 ㅁ',
#  '갓 ㅡ 겜 저 는 이 게임 엔딩 을 보 았 습니다 저처럼 퍼즐 을 좋아하 는 분 들 은 재 밋 게 하 ㄹ 수 있 습니다 저 는 어렵 지 않 게 플레이 하 었 더 ㄴ 것 같 네요',
#  '엘프 와 서 어 큐 버스 에게 죽창 을 꽂 을 뻔하 었 습니다 엘프 는 풀떼기 우유 나 마 시 라고',
#  '점 ㅎㅎㅎㅎ',
#  '굿 이 ㅂ니다 ㅎㅎ',
#  '일단 솔 플 하 어 보 았 는데 지금 까지 는 재미 있음 멀 ㄹ 티 잠깐 듣 어 가보 았 는데 채팅 이 라 덜 ㄴ가 모션 이 지금 기준 으로 안 보임 인사할려 고 아무 거 나 누르 어 보 았 는데 나오 는 것 이 없 더라 이것 때문 에 친구 말 고 다른 사람 이랑 멀티 하면 좀 질리 ㄹ 듯',
#  '오타쿠 씹뜨 억새 끼들 죽 어라 죽 어',
#  '캐쥬 얼 하 ㄴ 게임 이 ㄴ 줄 알 고 시작 하 려 하 었 다면 그냥 워 썰 ㄴ 더나 월오탱 이나 하 러 갈 는 것 이 좋 음 극 현 실적 이 고 조작 도 진짜 힘들 다 물론 이런 류 좋아하 면 만족 하 ㄹ 만하 ㄴ 작품',
#  '이지 는 무슨 내가 한글 을 쓰 지만 이겜 은 못하 겠 다 성격 급 하 시 ㄴ 분 은 패스 하 셈',
#  '소재 도 괜찮 고 꽤나 재미있 는 퍼즐 게임 이지만 버그 가 자주 발생 하 고 버그 발생 시 레벨 진행 이 불가능 하 다 재미 있 으면 뭐하 어 하 ㄹ 수 가 없 는데',
#  '언어 지원 이 라도 좀 하 어 주 시 던지 그리 고 초반 튜 토리 얼 비슷 하 게 가이드 있 거나 하 면 좋 을 터 이 ㄴ데',
#  '재밌 다 근데 왜 한글 이 아니 죠',
#  '지루 게임 이 타격 감도 불만족 스럽 고 성장 이나 강화 를 하 어도 나름 캐릭터 강 해지 는 맛 도 있 는데 그 맛 이 없 다',
#  '공략 을 보 아도 애초 에 엔 피시 위치 나 퀘스트 설명 길 찾 기 가 너무 힘들 다 중도 하차',
#  '그냥 메 기솔 팬 텀 페 인의 로 만원 에 나오 면 제격 이 ㄹ 듯',
#  '진짜 재밌 는데 현세대 로 하 기에 는 크래싱 이 많 아서 추천 은 못하 ㅁ',
#  '차라리 문명 주년 판 오케스트라 뮤직 모음집 에 그냥 팔기 시시 하 니깐 게임 을 구기 어 넣 었 다 보 는 것 이 낫 은 듯 도대체 어떻 게 나오 ㄴ 지 반년 이 다 되어가 는데 도 클라우드 저장 이 안 생기 는 것 이 ㄴ지',
#  '튜 토리 얼 하다 가 시간 넘 어서 환불 을 못하 네 쓸모 있 는 거 알 려 주 지 도 않 던데 나 는 동물원 만들 고 싶 었 지 경영 전략 을 하 고 싶 었 더 ㄴ 것 이 아니 ㄴ데',
#  '픽 세 ㄹ 겜 이 ㄴ가 예 귀엽 ㄴ 댕댕이 가 있 는가 예 근데 보드카 병 에 맞 고 낑낑대 는 것 은 약간 맴 찢',
#  '지브 리 작품 을 보 는 듯 하 어서 좋 네요',
#  '다른 차량 을 파괴 하 는 맛 이 일품 이 다',
#  '처음 접속 하 어서 하 ㄹ 때 는 괜찮 았 는데 두 번째 부터 접속 하 기 가 싫 더라',
#  '도전 과제 즙 짜 아 기용 게임 이 ㄴ 즙 게임 의 탈 을 쓰 ㄴ 도전 과제 묶음 도과 가 좀 고프 다면 잠깐 달리 어 보 도록 하 자',
#  '도트 는 잘 찍히 ㄴ 것 같 은데 설명 이 너무 불친절하 다 아무 생각 없이 퀘스트 대화 넘기 었 는데 다시 대화 하 어 보 면 최종 목표 만 알려주 ㄴ다 중간 과정 못 듣 었 는데 알 려 달 란 말 이 야',
#  '솔직히 환불 ㅈ ㄴ 하 고 싶 다 되 기 만 하면',
#  '그만 좀 튕기 어 제 에 발',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 정말 재밌 게 하 었 네요 게임 하 는 내내 웃음 을 잃 지 않 게 하 어 주 ㄴ 최고 의 게임',
#  '센죠 출항 이 걸 냐 구',
#  '온라인 로 딩 시간 좀 줄이 어 씨 뻘 럼 듣 아 기본 분 이야 쓋 빻 ㄹ 예상 하 지 못하 ㄴ 오류 좀 해결 좀 해보 아 개 같 은 락 스타 놈 들 아',
#  '손님 들 의견 이 라도 나오 면 좋을려 만',
#  '조작법 을 모르 겠 음 ㅠ',
#  '제발 하 고 싶 네요 실행 이 안됨',
#  '먹 튀겜 환불 좀',
#  '하프 라이프 를 잘 리메이크 하 ㅁ',
#  '갓 겜 역시 남쪽 주차 혼자 몰래 하 는 것 을 추천 부모님 이 보 았 을 때 매우 민망 해지 ㄹ 수 있음',
#  '게임 자체 는 나쁘 지 않 은데 조작 감이 거지 같 은 거랑 플레이 타임 이 적 은 거 빼 면 하 ㄹ 만하 ㅁ 물론 액션 게임 이 아니 고 퍼즐 게임 으로 생각 하 ㄴ다면 말 이 죠 원 짜리 라고 하 기에 는 많이 창 렬 함',
#  '사놓 고 잘 안하 게 되 ㅁ',
#  '기본 적인 플 탐 제외 하 면 갓 겜',
#  '오 아 게임 의 단순 하 ㅁ 에 한판 만 해보 고 환불 하 려 하 었 으나 의외 의 재미 에 즐 겜 중',
#  '주인공 이 썩 나쁘 지 는 않 았 고 액션 신 도 쉽 었 고 수집 요소 가 많 아서 좋 았 습니다 다 만 주인공 의 처형 씬 이 너무 오글거리 어요',
#  '옛날 근처 가게 에 늘 ㄴ 한국어 음성 지원 이랑 번역 이 다 되 어 있 는데 여기 ㄴ 왜 없 을까 스팀 에서 따로 지원 하 고 버그 문제 랑 복합적 이 다 보 니 안 만들 ㄴ 것 이 ㄴ가 라 라 의 면상 은 왜 사라지 고 눈깔 만 보이 는 것 이 ㄴ지 ㄷ ㄷ 그리하 여도 스토리 라인 만큼 은 맘 에 드 ㅁ',
#  '걍 노 잼',
#  '핵 노 잼',
#  '병 쉬 ㄴ 겜',
#  '제발 늘 ㄴ 나오 지 말자',
#  '오크 대사 스킵 이 시급 막 은 별로',
#  '멀티 가 더 재밌 는데 혼자 도 재밌 음',
#  '모르 겠 다 나한 터 이 ㄴ 어지럽 기 만 하 었 다',
#  '추억 의 고전 게임 이 ㄴ 팩 맨 이 ㅂ니다 레트 로 오락실 에서 만 하 ㄹ 수 있 는 게임 을 스팀 에서 하 ㄹ 수 있 게 되 어 정말로 영광 이 ㅂ니다 앞 으로 도 오락실 게임 들 이 스팀 을 통하 어 많이 나오 았 으면 좋 겠 습니다',
#  '이것 이 무슨 만원 이 야',
#  '개 어려움',
#  '게임 이 재미있 기 는 한데 한국인 이 플레이 하 려면 한글 패 하 지 같 은 것 도 깔 아야 되 고 그래서 한글 패 하 지 나오 기 까지 는 않 살 는 것 이 낳 아요',
#  '병신 같 은 조작 감 얼마 없 는 유 저수 기준 아시아 설 겨우채움 팀 밸런스 격차 최적화 잘되 ㄴ 건 아니 다 적 은 커스 터 마이 징 복붙 레벨 제한 이 심하 ㅁ 서버 연결 문제',
#  '왕좌 의 게임 모르 면 사지 말자',
#  '질병 주식회사 를 인체 하나 버전 으로 압축 하 ㄴ 게임 생물학 주식회사 복수 이 ㅂ니다 플레이 영상 에 나오 는 대로 질병 을 부여 하 어 사람 을 죽이 거나 치료 하 어 살리 는 게임 이 ㅂ니다 그리고 스트레스 는 만병 의 근원 이 ㅂ니다',
#  '한글 이 없 다 ㅎㅎㅎ 그리하 여도 재밌 음',
#  '친구 분 들 과 즐겁 ㄴ 범죄 액션 게임 은 어 어 떠시 온 짓',
#  '또 속 았 다',
#  '얼굴 에 기름 때 묻히 고 차량 정비공 이 되 어 보십 시다 엔진 오일 교환 정도 는 스스로 하란 말 야',
#  '이딴 거 하 ㄹ 시간 에 딸딸이 같 은 유익 하 ㄴ 곳 에 시간 을 쓰 어 보 는 것 은 어떻 ㄹ까',
#  '에임이 좋 든 안 좋 든 에이 ㅁ 연습 은 하 어야 만 하 ㄴ다',
#  '재미 는 있 는 데 같 은 패턴 이 라 노가다 도 상당 하 고 해상도 비율 이 ㄴ데 그래픽 이 좋 은 것 같 으면서 도 기체 그래픽 은 조잡 하 ㄴ 느낌 이 고 무기 종류 도 부족하 다고 생각 하 ㅂ니다',
#  '플래시 게임 이 ㄴ 줄',
#  '최종 보스 를 가기 위 하 ㄴ 시련 들 을 난이 도 점점 상향 시키 더니 이젠 아예 깨 지 도 못하 게 상향 시키 어 두 었 네 이것 을 깨 라 고 만들 어 두 ㄴ 거 이 냐 유 튜브 네이버 등등 공략 을 찾아보 아 도 없 어 ㅁ ㅊ',
#  '게임 을 안하 는 것 이 해피엔딩 내가 미안 하 어',
#  '오 아 진심 이것 이 게임 이 ㄹ까 라고 생각 이 들 ㅂ니다',
#  '뭐 가 중요 하 어 무료 자나',
#  '턴 로딩 이 길 다는 거 빼 고 갓 겜 이 ㅂ니다',
#  '네 놈 들이 이구역의 미친놈 이 면 나 는 이것 이 임의 미친놈 이 다 미치 ㄴ 약 쟁이 놈 들 을 미친놈 들 이 때리 어 잡 는 잡 입 액션 게임 목격자 가 없 으면 암살 이 ㅁ',
#  '사람 들 이 아무리 명작 이 라고 하 어도 시간 이 많이 흐르 ㄴ 지금 처음 접 하기 에 는 게임 이 너무 불친절하 다',
#  '아무리 비참 하 고 잔혹 하 ㄴ 지옥 에 떨어지 ㄴ다 하 어도 네 가 슬퍼하 는 것 보다 ㄴ 천 배 만 배 좋 으니까 아 아 아 아 아 아 행복 하다 이 면 행복 하다 이 면 행복 하다 이 면 되 었 어 몇 번 이 든 뭐 든 널 위 하 어 기도 하 ㄹ게 ㅠㅠㅠㅠㅠㅠ',
#  '정 발 이 안 되 어 스 어 한글 도 아니 ㄴ데 다그 아 멀티 는 진짜 별로 하 지만 싱글 의 스토리 와 재미 는 콜옵 답 게 진짜 최고 이 었 다 멀 ㄹ 티 를 하 고 싶 다면 이것 대신 에 블랙옵스 를 추천',
#  '쓰레기 게임 만들 어 놓 았 네 아 돈 아깝 어 죽 겠 다 진심 난이 도 개 높이 어 노 아서 하 지 도 못하 겠 고 돌파 도 안되 어 뭐 도 안되 어 현질 해 라 이 거지 게임 이딴 식 으로 만들 니까 사람 들 이 안사 짓 어 유 쓰레기 게임',
#  '세일 하 ㄹ 때 사 었 는데 정말 재밌 음 느 ㄴ 총 추가 되 는 거 사 는 것 이 좋 음',
#  '난이도 만 더럽 게 높 은 게임 이 ㅂ니다 그냥 어렵 게 만 만들 려 는 티 가 너무 날 는 게임 임 무엇 을 이렇 게 까 지 하 었 나 싶 을 정도 제작사 보 니까 어차피 인 디 회사 로 찌지 ㄹ 대 이 다 죽 을 회사 같 은데 그래서 그렇 ㄴ가 봄',
#  '배 보다 배꼽 이 더 크 ㄴ 게임 회수 는 하 었 으니 만족 하 고 갈 ㅂ니다 끄 어 억',
#  '배경 분위기 리 마스터 버전 이 더 안 좋 다고 생각 하 ㅁ',
#  '에지오 사가 의 마지막 이야기 에 지 오 사가 는 다 재밌 다는 평가 가 대부분 이 지만 이때 부 터 이 었 을까 유비 게임 이 조 오 오오 올르 아 반복 적 이 고 무의미 하 ㄴ 매 점령을 시작 하 ㄴ 것 이',
#  '게임 하다 가 멀미 나 는 사람 들 은 플레이 자제 하 시 기 를 좁 은 동굴 어둡 고 방향 감각 이 발휘 되 ㄹ 수 없 는 맵이 많 아 필자 는 장시간 플레이 를 하 지 못하 고 결국 환불 처리 하 었 습니다',
#  '개발자 들 싹 다 잡 아다가 지하 벙커 같 은데 가두 어 두고 후속 작 만들 게 감금 시키 고 싶 다',
#  '농사 게임 좋아하 면 재 밋 음',
#  '하 ㄹ 거 없 을 때 하 기 좋 은 게임 다만 조작 감 이 좀',
#  '이것 을 게임 이 라고 만들 었 냐 시 벌 졸리 어 뒤지 는 줄 알 았 네 눈 에 보이 지 않 는 투명 벽 이 있 지 를 않 나 배 경이 다 똑 같어 이거 하 ㄹ 바 에 는 윈도우 에 기본 으로 깔리 어 있 는 게임 이 더 재밌 다는 것 만 알아두 어 라',
#  '이 게임 만 소리 가 안 나 네 미치 겠 네',
#  '갸 꿀 잼 킹 갓 겜 이 ㅂ니다 묻 지 도 따지 지 도 말 고 사 세요',
#  '도망가',
#  '저격 소총 만 얻 으면 신이 되 ㄹ 수 있 는 게임 슬 나 이 푸 어 엘리트 를 사 는 것 이 현명 하 어 보이 ㄴ다',
#  '세계관 안 에 푹 빠지 어서 게임 하 ㄹ 수 있음',
#  '주인공 은 더럽 ㄴ 흙 수저 격투 선수 의 삶 을 극복 하 어 나가 는 이야기 이 라면 플레이어 는 그냥 노가다 만 하 는 이야기 이 다 모바일 겜 버전 으로 도 있 어요 한글 이 공식 이 되 었 네요 그리하 여도 노가다 는 안 사라지 ㅁ',
#  '시간 이 지 나 다시 플레이 하 어도 재미있 습니다 명작 은 명작',
#  '나 는 다른 사람 들 과 평화 롭 게 같이 청소 를 하 는 모습 을 상상 하 고 게임 을 사 었 지만 정작 그 넓 은 공간 을 청소 하 는 것 은 나 혼자 이 었 다 그리하 여도 재미 는 있다 ㅎ',
#  '돈 주고 삿 늘 ㄴ 데 계속 게임 상 에서 튕기 면 어쩌 라는 것 이 ㄴ가요',
#  '무기밸런싱 이 망하 ㄴ 겜 저격 총 이 ㄴ지 슬러그 타 ㄴ 즉사 산탄총 이 ㄴ지',
#  'ㅋㅋ 튜 토리 얼 해보 았 는데 딱 보 아도 재미없 어 보이 네요 비추이 ㅂ니다',
#  '패치 를 거듭 하 어도 나아지 ㄹ 기미 가 보이 지 않 는 노 답',
#  '막 금구 은신 태세 명 들어가 면 나 만 개 치 어 맞 는 기적 의 발 겜',
#  '버그 갓 겜 진행 하 다가 버그 걸리 어서 세이브 날림 ㅅ ㄱ',
#  '한국어 좀 추가 좀 하 어 주 어 라 퀘스트 래퍼 토리 만 대충 알 고 파악 하 어서 퀘 깨 ㄴ다 열심히 하 ㄹ라 그리하 여도 이러 더 가 아 외국어 공부 만 열심히 하 게 생기 었 어',
#  '지금 평가 하기 에 는 이르 지만 어쨌든 나오 아서 좋 네요',
#  '한글 패 하 지',
#  '망 함 ㅅ ㄱ',
#  '개 허 접하 ㅁ',
#  '오 대박 카드 게임 이 ㄴ 것 같 은데 은근 잼 있 네요 한글 패 하 지 만 되 면 몰 ㄹ 입도 짱 이 ㄹ 것 같 은데 머 몰르 아도 그림 으로 친절히 설명 되 어 있 고 게임 하 는 되 는 언어 가 크 게 지장 은 없 네요 단지 스토리 가 먼지 를 잘 모르 ㄹ 뿐',
#  '초심 잃 은 초 딩 망 겜',
#  '단순 하 ㄴ 추억 팔 이 가 아 아니 ㄴ 눈 과 귀 를 즐겁 게 하 어 주 는 새 롭 ㄴ 게임',
#  '갓 겜 예전 에 턴 제 알 ㄹ 피지 에 길들 ㄹ 여진 아 아 제 들 은 반드시 해 바 바',
#  '게임 이 엉성 하 다고 하 ㄹ까 초반 에 게임 이 진화 하 는 것 은 재밌 었 지만 결국 나중 에 고정 이 고 게임 이 좀 단촐하 다',
#  '일단 이 게임 은 훌륭 하 ㄴ 것 이 임성 리얼 하 ㄴ 분위기 가 정말 마음 에 드 ㅂ니다 그래픽 도 좋 습니다 하지만 위 의 것 들이 아무리좋더라도 최적화 가 초창기 베 고 급 이 라 즐기 기 힘들 ㅂ니다 추후 에 최적 화가 개선 이 잘 되 ㄴ다면 추천 드리 겠 습니다',
#  '진짜 개 재밌 네 뱉맨 공식 한글 이 아니 란 것 이 너무 아쉽 다',
#  '음 괜찮 네요 멀티 하 려면 랑 한판 하 어야 되 ㅁ 그 거 좀 설명 좀 하 어 노 아 라',
#  '네 아직 없 으시 다구요 돈 값 은 하 ㅂ니다 지구 를 지키 시 어야 죠',
#  '챌린지 가 너무 금방 끝나 ㅁ',
#  'ㄴ ㅏ 는 ㄱ 끄 ㅁ 눈물 을 흘리 ㄴ ㄷ ㅏ 모니 ㅌㅓ 속 의 그대 와 맺어 질 ㄹ 수 없 는 ㅅㅏ랑 을 알 ㄹ ㄱ ㅣ 에',
#  '한편 의 동화 세 번 정도 다시 보 았 는데 많 은 생각 을 하 게 하 ㄴ다 참고 로 한글 화 안되 어 있 어도 이해 하 ㄹ 수 있 는 제품 이 ㅂ니다',
#  '겉 으로 보이 는 것 보다 알차 ㄴ 게임 싸 ㄴ 가격 이 라 부담 도 없 고 가격 이상은 뽑아내 ㄹ 수 있 을 것 이 ㅂ니다',
#  '시뮬레이션 은 정말 내 취향 이 아 님 재미있 는 것 도 아니 고 트렉터 타 고 지금 내가 뭐하 러 멍하니 있 나 싶 은 생각 이 가장 먼저 드 ㅁ',
#  '급식 때 복 돌 로 하 고 미안 하 어서 구매 하 ㅁ',
#  '핑 만 안 튀 었 으면 제대로 하 ㄹ 만하 ㄴ데 영웅 질르 어 놓 은 거 개 아깝 다',
#  '로 시작하 어서 튜 토리 얼 에 시간 쓰 었 는데 도 재밌 음 스테이지 마다 새 롭 ㄴ 게임 하 는 기분',
#  '만원 으로 옷 을 사 거나 밥 을 사 아 먹 으시 ㅂ쇼 오랜만 의 한글 화 이 라 기대 하 었 는 데 중사 를 병장 이 라 하 지 않 나 대령 이 라 했따 가 대위 이 라 하 었 다가 개판 팔 ㄴ 멀티 는 전통적 으로 이 니 넘어가 고 싱글 은 신선 하 ㄴ 점 도 있 었 지만 넘 나 짧 은 것 첨 에 라이 언 일병 구하 기 느낌 난건 좋앗 음',
#  '돈 지랄 에 이기 ㄹ 수 가 없 구나',
#  '업데이트 하 고 나 서 런 처 가 바뀌 ㄴ 이후 로 안되 ㄴ다고 파이 락 시스 시발 놈 의 새 끼들 아 아 로도 하 어도 안되 ㄴ다고 옛날 런 처 로 켜 도 안 되 ㄴ다고 내가 하 었 더 ㄴ 세이브 돌려내 라 개 새 끼들 알',
#  '오 아 우도 안해 보고 엘 더 스크롤 전작 들 도 듣 기 로 만 듣 었 는데 한국 게임 보다 묘하 게 끌어당기 는 것 이 있 네요',
#  '만 못 하다 그리하 여도 애정 으로 따 아 봉 주 ㄴ다 늘 ㄴ 플스방 에서 하 어서 라이브러리 에 는 없 는데 따 아 봉 못 주 ㄴ다 딱 까 아 지이 었 어',
#  '늘 ㄴ 믿 고 거르 면 되 ㄴ다 스카이 림 생각나 는 토 나오 는 팅 김 바이오 쇼크 최악 의 넘버링 카드 먹 을리 어 고 억지로 하 ㅁ',
#  '간단 하 게 말 하 자면 나 레이터 의 지시 에 플레이어 가 어떻 게 행동 하냐에 따르 아 엔딩 이 바뀌 는데 하다 보 면 이 게임 이 내 생각 을 읽 고 있 는 듯하 ㄴ 기분 이 들 ㄴ다 그냥 일단 사 고 보 자',
#  '우선 처음 하 는 사람 입장 은 적성 에 않 맞 을 수 있 다 너무나 재밌 어 보이 는데 재밌 게 하 기 가 힘들 다 생각 보다 섬세 하 ㄴ 초현 실적 이 였 고 플레이 도 처음 하 어 보 아서 낯설 었 다',
#  '시간 이 너무 아깝 습니다 절대 하 지 말 시 ㅂ시오 차리 리 자살 하빟 ㅅ ㅂ',
#  '나 는 재밌 는데 친구 는 죽 을라고 하 ㅁ',
#  '웃기 고 재미 잇 어요',
#  '사람 이 있 어야 하 죠 ㅣ 받',
#  '시공간 을 초월 하 ㄴ 능력 을 갖 게 되 ㄴ 이야기',
#  '아 아 휴 진짜 이 겜 왜 이러 냐 어제 부터 로그 인 만 하면 로그 아웃 돼 면서 되 어 다 말 다 하다 때려치 어 라 이따 구로 하 ㄹ 꺼 이 면 이렇 ㄴ 그지 같 은 환경 으로 에보 도 온라인 으로 하 ㄴ다 내 ㅋㅋㅋ 미치 ㄴ 거지 ㅋㅋㅋㅋ',
#  '재미있 는데 너무 잘 튕기 ㅁ ㄴ ㄷ',
#  '이 정신병자 새끼 들 이 태반 이 ㄴ 정공 겜 계급 세이브 로드 에 랜뽑하면 서 자기 계급 올려놓 고 잘하 ㄴ다고 자위 하 는 새끼 들 이 존나 많 다 아무리 하 ㄹ 게임 이 없 어도 이딴 겜 상종 도 하 지 말자 시발 내 잃어버리 ㄴ 시간 시간',
#  '어렵 지 않 은 게임 이 고 나름 잘 만들기 는 하 었 지만 저 는 별로 재미 를 느끼 지 는 못 하 겠 네요 플레이어 가 직접 추리 하 는 부분 은 크 지 않 고 단서 수집 이 주되 ㄴ 활동 이 ㄴ데 좀 지루 하 었 어요',
#  '히틀러 가 짝 불알 이 ㄴ 이유 를 알리 어 주 는 게임',
#  '게임 은 잘 만들 ㄴ 거 같 기 는 한데 주인공 이랑 주변 인물 들 행동 보 면 속터지 어 미치 ㄹ 지경 게다 가 주인공 은 영웅 병 걸리 었 는지 지 혼자 나대 고',
#  '자꾸 실행 이 꺼지 네요 왜 죠 사 양은 풀옵 도 돌아가 는데 꺼지 는 이유 는 뭐죠 이 ㄴ데',
#  '이 게임 이 원 이 라 고요 인공지능 턴 도 겁 나 아 길 네요',
#  '계의 혁신 이 었 더 ㄴ 갓 겜 콜옵 모 원 마일 하이 베테랑 존나 어렵 다 ㅠㅠ 깨 느라 한 번 은 죽 은 듯',
#  '사천성 아류 쓰레기 게임 할인율 아무리 높 아도 절대 구매 하 지 말 ㄹ 것',
#  '완전히 좃 망 겜',
#  '길 게 적 을 필요 없이 차라리 스트롱 홀드 를 하 세요',
#  '즐겁 게 즐기 ㄴ 게임 초반 에 는 힘들 어서 허덕이 지만 업 글 을 통하 어 점차 강하 어 지 므로 회 차 보스 까지 늘 ㄴ 무난 하 게 잡 을 수 있 습니다 회 차 가 좀 힘들 ㄴ 거 같 구 저 의 경우 에 는 추가 보스 들 이 어렵 어서 아직 못 깻 네 용 ㅠ 한글 패 하 지 도 있 으니 더더욱 추천',
#  '멀미 존나 심하 ㅁ 마지막 쳅터 는 선 넘 음',
#  '게임 그리 많이 안하 다가 왜 이 ㄴ지 모르 게 접하 ㄴ 게임 이 ㄴ데 이렇 게 재미 가 있 을 수 있 나 싶 다 바라 는 거 많 지 않 으면 재미 는 보장 되 ㅁ',
#  '트레일러 보 면서 화살 튕기 어 내 ㄹ 수 있 는 거 처음 알 았 음',
#  '최적화 가 너무 구리 ㄴ 데',
#  '왜 하 는지 모르 겠 는 게임',
#  '진짜 게임 중 에서 최악 그 자체 알 니 서버 하나 에 사람 수가 명 정말 최악 그 자체',
#  '점점 현질 안 하 고는 힘들 게 만들 는 회사 다음 작 은 앵 간 히 하 어야 되 는데 재미 는 있다 만 그냥 한글 화 이 기에 살 ㄴ 느낌 이 더 강하 ㅁ',
#  '업데이트 가 느 어 어 어 어 어 어 어 어 어 어 어 무 느리 다 진심 너무 느리 어 한글 화 도 아니 ㄴ데 업데이트 마저 느리 니까 이것 을 나 가 왜 사 었 나 싶 은 마음 이 듣 어 버리 ㅁ ㅡㅡ',
#  '매우 재미있 는 게임 갓 게임',
#  '꼭 사셈 까지 사셈',
#  '일루 전 야 겜 여캐같 은 애 들 이 뛰 다 기면 서 빤스 보여주 면서 싸우 는 찬 바라 게임 이 다 그리고 음 적 캐릭터 다 프트 펑크 닮 았 어 어 어 그리 고 재미 는 없 어',
#  '아주 재미있 는 게임 이 다',
#  '꽤나 순발력 요하 는 게임 처럼 느긋 하 ㄴ 마음 으로 하려 이 다 가 ㄴ 당황 하 ㄹ 듯',
#  '마우스 라서 정말 편 하 ㄴ다 이제 곳 자주포 도 나오 ㄹ 꺼 고 인원수 나 좀 늘리 어 주 지 워 것 이 이놈 들 핑 폭 도 조금 있다 하 지만 키보드 와 마우스 라서 좀더 편하 ㄴ 것 같 다',
#  '카 메카닉 시뮬레이션 중 입문 용 으로 ㄴ 좋 은 게임 이 ㅂ니다 기본적 이 ㄴ 차량 구조 에 대하 어 선 알 ㄹ 수 있 으나 생략 되 어 표현 이 안되 ㄴ 부품 도 많 으니 게임 으로 차량 정비 를 진지 하 게 하 고 싶 으시 ㄴ 분 들 은 다른 작품 을 추천 드리 ㅂ니다',
#  '나름 대로 좋 은 시간 을 보내 었 더 ㄴ 것 같 습니다 하지만 여기 에 돈 을 쓰 ㄹ 생각 은 드 ㄹ지 않 는군요',
#  '으악 내 돈 일단 게임 화면 부터 가 아 혀 ㅁ',
#  '답답 하 어도 하 ㄹ 만 함',
#  '게임 까지 개발 을 하 ㄹ 줄 은 모르 았 습니다',
#  '동생 이 너무 쌔 ㅁ 스토리 는 짧 고 멀티 는 재미없 음 허 ㅁ 블 ㄹ 이 이 라 사 었 지 아니 면 인 디 게임 보다 못 하 ㄴ 수준 거기 다가 호 러 에서 벗 어 나 미래로 변 하 ㅁ',
#  '재미 있음 단점 은 초 반부 퀘스트 깨 는 것 도 너무 지루 하 고 그냥 초 반부 가 진짜 지독 하 ㄹ 정도 로 재미없 다 수정 후반부 는 더 재미없 다',
#  '원피스 해적 무쌍 나름 괜찮 은 재미 잘 만들 어 지 ㄴ 게임 이 네요 그리고 곧 나오 ㄹ 도 기대되 네요',
#  '쩔',
#  '내 생의 최악 의 순간 이 게임 의 구매 버튼 을 누르 ㄴ 그 순간',
#  '도전 과제 해금 용 게임 이 다 솔직히 게임 이 라고 부르 ㄹ 수 있 을지 조 차 의문 이 다 도전 과제 를 위하 어 선 회 차 가 필수 소요 시간 은 약 분 내외',
#  '점프 도 어렵 고 금방 끝나 ㅁ',
#  '뭐 부터 먹 을지 행복 하 ㄴ 고민 이 들 는 뷔페 남 들 이 한계 를 보 ㄹ 때 나 는 가능성 을 보 았 다',
#  '재밌 었 구요 엔딩 까지 딱 시간 걸리 었 는데 아주 좋 아요',
#  '산지 일 만 에 플레이 타임 시간 돌파 이거 생각 보다 재밌 습니다 굳이 씬 안 넣 었 어도 팔리 었 을 거 같 은데',
#  '한방 이 면 너 도 한방 나도 한방',
#  '아 아 포 칼 립스 헬기 가 날아다니 고 현대 무기 를 사용 하 는 배경',
#  '확장 팩 이 하나 밖에 없엉',
#  '알 고 하 ㄴ다면 재밌 는 게임 이 길 ㄴ 하 겠 지만 모르 고 하 면 뭐 가 무엇 이 ㄴ지 도 모르 ㅁ',
#  '꿀 잼 시간 갈 는 줄 모름 가끔 프리 징 이 있 어서 짜증 남 유 플레이 필요',
#  '매칭 이 안되 는데 무슨 게임 을 하 라는 것 이 ㅂ니까 ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ',
#  '재밌 고 그래픽 도 좋 은데 왜 많이 안하 지 폰 게임 수준 이 길 ㄴ 하지만 크 ㄴ 화면 으로 보 아서 좋음재밋읍니 다',
#  '가 아 성비 가 뛰어나 ㄴ 작품 이 지만 쌓 ㄴ 가격 만큼 조금 나사 빠지 ㄴ 부분 도 있 는 액션 다른 건 괜찮 았 지만 상태 이상 을 걸 는 장애물 이나 적이 너무나 도 짜증나 었 다 부담 없 는 가격 이 므로 구매 를 말리 진 않 겠 지만 기대 가 크 면 실망 하 ㄹ 수 도 있 는 정도 의 작품',
#  '디펜스 게임 을 즐기 시 ㄴ다면 추천',
#  '버그 덩어리',
#  '정말 재미있 는 그렇 ㄴ데 아직 컨텐츠 는 부족',
#  '이거 왜 에러 뜨 어서 실행 도 안되 나요',
#  '노마 더 게임',
#  '한번 하 면 하 ㄹ 것 이 없 음',
#  '원작 에서 불만 이 었 더 ㄴ 점 이 완벽 하 게 개선 되 ㄴ 점 이 좋 았 습니다',
#  '제대로 좀 만들 어라 한 시간 에 번 씩 은 튕기 니 제대로 게임 을 하 ㄹ 수 가 없 네요 시간 넘 어서 환불 도 안되 고 만원 넘 는 돈 이 그냥 허공 으로 날아가 ㅁ',
#  '빨리 내 셈',
#  '하 ㄹ 만 은 하나 서버 노 답 에 개 적 호 아 온갖 버그 가 난무 하 는 겜 이 돈 주 고 차라리 아크 서 바이 벌 이나 러스트 를 하 는 것 을 추천 하 ㄴ다',
#  '컨트롤 더럽 게 불편 하 ㅁ 외 어 있 는지 모르 겠 는 회피 시스템 카메라 돌리 는 것 도 불가능 하 ㅁ 여러 분 은 싸 다고 사지 마세 요',
#  '역시 갓 작품',
#  '이 게임 시리즈 는 전부 다 이상 하리 만치 똑같 은 양산 게임 이 라는 느낌 을 지우 기 가 힘 드 ㅁ 퍼즐 게임 이 ㄴ 척 하 는 리듬 게임 잦 은 버그 로 인하 ㄴ 재 시작 특히 마지막 타 ㄴ 에 서 버그 가 걸리 면 메 ㄴ 붕 하 는 현상 이 노랗 ㄴ 벽 이 움직이 지 말 아야 하 는데 움직이 ㄴ다 거나',
#  '많 은 아이템 과 제작 조합 등 매우 컨텐츠 가 많 음',
#  '뭔 가 잘 만들 었 는데 제자리 를 돌 는 느낌 잔 버그 도 꽤 있 고 노가다 이 라는 느낌 도 많이 들 지만 제일 아쉽 ㄴ 건 옆 동네 게임 에 비하 어 덜 ㄴ 전수 도 대략 개 로 한정 되 어 있 고 마을 도 실질적 으로 이용 하 ㄹ 수 있 는 늘 ㄴ 도서 관맵 연습장 이 세가지 밖에 없 음',
#  '화나 ㄴ다',
#  '우리나라 정치판 을 잘 묘사 하 ㄴ 게임',
#  '성장 의 재미 기술 쓰 는 재미 가 있 다',
#  '아르 마가 더 좋 습니다',
#  '괜히 조선인 믿 었 다가 피 봄',
#  '이 게임 의 분량 에 한번 놀라 었 고 게임 클리어 하 ㄹ 때 춤추 는 거 보 고 한번 더 놀라 었 다',
#  '처음 시작 부분 에 꼬리 아 님 머리 하면서 동전 던지기 하 는 부분 에서 계속 튕기 는데 이거 어떻 게 되 ㄴ 것 이 ㄴ지 모르 겠 네요 ㅠㅠ',
#  '주사위 는 던지 어 지 었 다',
#  '게임 을 하다 보 면 알 ㄹ 수 있 다 아무 의미 가 없 다는 것 을',
#  '버스 가 왜 늦 나 우리 지역 교통 은 왜 이따 군가 맨날 욕하 시 는 분 들 께 추천 하 는 게임 버스 를 빨리 보내 고 싶 어도 못 보내 고 교통 을 좋 게 만들 어 주 고 싶 어도 도로 사정 때문 에 혈압 만 오르 는 교통 회사 들 의 고충 을 충분히 느끼 ㄹ 수 있 는 게임 이 ㅂ니다',
#  '가족 끼리 사랑 에 빠지 는 게임 이 라니 망측 스럽 어요',
#  '이거 어 어 어 어 어 어 엄처 어 어 엉 어렵 습니다 근데 원 값 은 해 요 시간 훅 갈 네요',
#  '재미없 음 스 어 벌 는 한 자리 수고 하 는 사람 도 거의 없 다 이거 하 ㄹ 바 에 는 그 돈 아 아 끄 어서 땋 ㄴ 겜 사라 그래픽 부터 모든 것 이 비호 감',
#  '고 블린 환풍구 버그 에서 포기 하 었 습니다',
#  '음 커 ㄴ 터 이 ㄴ 즈 너무 없 음',
#  '당신 은 서부 시대 카우보이 들 이 레버 액션 윈 체스터 라이플 을 들 고 스핀 코킹 하면서 빵빵 쏘 는 혈투 를 동경 하 시 었 습니까',
#  '것 이 망 겜',
#  '재밌 는데 가격 만 싸 었 으면 좋 았 을 듯 나 는 싸 게 사 아서 만족 하 ㅁ 그 ㄴ데 욕 을 너무 먹 어서 사람 들 이 빠져나가 니까 큐 가 느리 어 짐 ㅠㅠ',
#  '생각 보다 플레이 타임 도 좋 고 그렇 게 질리 지 도 않 고 은근히 꿀 잼',
#  '플래시 스마트 폰 타워 디펜스 중 에서 젤 추천 하 고 싶 은 작품 난이도 밸런스 가 꽤 잘 되 어 있 어서 지루 하 지 않 음 영웅 업 글 을 위하 어서 반복 이 아주 약간 필요 하 기 는 하지만 굳이 디 럭스 나 에디션 을 사 ㄹ 정도 는 아니 ㅁ',
#  '현질 필수',
#  '정말 재미있 었 다 그런데 후속 작 은 안 나오 고 계속 만 나오 ㄴ다 너무하 ㄴ 거 아니 ㄴ가',
#  '멀미 조심',
#  '한글 패 하 지 나오 ㄹ 때 까지 존버 하 겠 습니다',
#  '컨셉 은 좋 았 으나 시드 마이어 의 이름 값 이 아깝 ㄴ',
#  '희대 의 갓 겜 그 니까 한글 패 하 지 좀 하 어 주 어 뉴 비 유입 이 시급 하 ㄴ 게임',
#  '로그 라이크 게임 류 는 처음 해보 는데 처음 에 적응 하 기 가 어렵 지 하 면 하 ㄹ수록 재밌 는 게임 이 ㅂ니다 재밌 어요 하세 요 두 번하 세요',
#  '심플 하 면서 도 재밌 는 레이싱 게임',
#  '처음 플레이 하 었 을 때 그 공포감 조작 감 타격 감 을 잊 을 수 가 없 습니다',
#  '나폴레옹 프랑스 만 고르 ㄹ 수 있 을 줄 은 모르 았 네',
#  '하 다가 졸 았 음 원 정도 이 면 살만 하 ㄹ 듯',
#  '나 가 제일 싫어하 는 몬스터 피하 기 게임',
#  '일단 이 디 엘 씨 는 걸르 어야 만 하 ㄴ다 정말 구리 이 다',
#  '역대 해본 콜 옵중 가장 다이나믹하면서 도 벨 런 스가 잘 맞추 어 지 ㄴ 게임 멀티 유저 가 갈수록 줄어들 ㄴ다는 것 이 너무나 도 아쉽 다',
#  '할인 하 ㄹ 때 구매 하 어서 코옵으 로 가볍 게 즐 기기 에 는 괜찮 았 더 ㄴ 게임',
#  '와버그가없서나 만',
#  '고인물 천지',
#  '집중 하 어서 하다 보 니 분 이 끝 나 있 네요 정식 판 만 기다리 어 지 어요 더 강하 ㄴ 총 이 필요 하 ㅂ니다',
#  '게임 은 재미있 으나 엔딩 이 좀',
#  '년 만 에 위닝 을 구매 하 었 습니다 매번 평 이 복합적 이 라 덜 ㄴ가 좋 지 않 아서 구매 를 꺼리 었 는데 오랜만 에 시리즈 를 사 아서 해보 니 만족 스럽 고 좋 네요',
#  '흠 재밌 기 는 하지만 조금 어렵 ㄴ 감 이 있 습니다 저 는 뒤 로 갈수록 막히 어서 공략 을 보 았 습니다',
#  '난이도 가 너무 높 네요',
#  '이거 업데이트 한 뒤 로 갑자기 문제 거리 면서 온라인 이 안 되 어요 왜 그러 ㄴ 것 이 죠',
#  '뭐 한글 화 ㅋㅋㅋㅋ 좋 다 지금 갈 ㄴ다 기다리 어 라',
#  '도로 시 한테 너무 몰입 하 면 우울 해지 ㄹ 수 도 있 어요 근데 그거 빼 고는 재밌 는 듯 그레텔 얼굴 너무 무섭 어 ㅜㅠ 일 내내 보 았 더니 꿈 에서 나오 ㄹ 거 같애여',
#  '갓 흥 겜 이 다',
#  '되게 재밌 어 보이 어서 구매 하 었 는데 설치 하 고서 깔 았 다가 지우 기 만 몇 번째 이 ㄴ지 모르 겠 네요 왜 자꾸 작동 이 중지 되 었 다고 뜨 ㄹ까요 설정 이 안 맞 나 괜히 돈 주고 사서 환불 하 고 싶 네요 ㅠㅠ',
#  '시리즈 물 은 꼭 잇 어서 하 는 스타일 이 라 구매 하 었 는데 그냥 크 ㄹ 레 메 ㄴ 타인 펜 심 으로 플레이 하 었 네요',
#  '클래식 하 ㄴ 게임 이 라지만 슈퍼 마리오 는 지금 하 어도 재밌 는데',
#  '이 게임 하 시 면 심령 고 자가 되 ㄹ 수 잇 다 를 느끼 고 정말 명작 이 ㄴ 거 같 다는 생각 과 함께 게임 을 깨 버리 어서 정말 대단 하 ㄴ 게임 이 다',
#  '추상적 이 고 상징적 이 ㄴ 스토리 가 간단 하 ㄴ 퍼즐 에 몰입 하 ㄹ 수 있 게 하 어 주 ㅂ니다 그런데 지도 와 리셋 버튼 이 화면 에 뜨 지 않 고 설명 같 은 것 드 ㄹ 도 뜨 지 않 는 건 버그 이 ㄴ가요 이것 때문 에 지도 가 필요 하 ㄴ 관 부 터 는 진행 이 안되 네요',
#  '지역 락 풀리 어서 살 ㄹ 때 꼬쇼 안 하 어도 되 ㅁ ㅅ ㄱ',
#  '아직 개발 중',
#  '탐욕 이 개인 에게 어떻 게 반영 되 는지 잘 와닿 는 작품 이 네요 도 기대되 네요 추천 하 ㅂ니다',
#  '그냥 설치 하 ㄴ 뒤 에 게임 을 실행 하 니까 검 은 창 만 보이 고 실행 이 안되 네요',
#  '팦 바 개 훔치 어 간 새기 들 ㄹ 때문 에 접 음',
#  '를 할거 이 면 를하 덜 ㄴ가 왜 코옵 하 는데 지 들 만 알아듣 는 용어 쓰 고 지랄 일 ㄹ까 난 게임 하 러 오 ㄴ 거지 병신 같 은 군사 용어 배우 러 오 ㄴ 것 이 아니 ㄴ데',
#  '게임 재밌 어요 여러분 아주 훌륭 하 ㅂ니다 그리고 새로 시작하 시 는 분 들 가문 어디 가 입하 시 ㄹ지 모르 시 겠 다면 저 한테 귓 말 보내주 세요 같이 천천히 가보 ㅂ시다 지역 은 운 천 이 ㅂ니다',
#  '맵만 크 면 뭐하 어 하 ㄹ게 없 잖아',
#  '얄팍 하 ㄴ 스페이스 슈터 게임 워낙에 스페이스 가 들어가 는 게임 중 복잡 하 ㄴ 물건 이 많 다 보 니 이 게임 처럼 얄팍 하 ㄴ 것 도 나름 매력 있다 장르 에 대하 ㄴ 기초적 이 ㄴ 지식 만 있 다면 아주 가볍 게 즐기 ㄹ 수 있 는 게임',
#  '공기 청정기 주인공 과 손발 이 말리 비틀 어 지 는 스토리 를 빼 고 나 면 의외로 하 ㄹ 만하 ㄴ 수작 겜',
#  '도저히 그 많 은 돈 을 들이 어 만들 었 다 고 는 보 ㄹ 수 없 는 퀄리티 뻔 하 ㄴ 스토리 졸작 도 아니 지만 펀 딩 하 ㄹ 때 돈 을 생각 하 면 영락없 는 졸작 정말 딱 그저 그런 게임',
#  '프레임 이 느리 ㄴ 거 같 은 렉 또는 끊기 ㅁ 현상 돈 아깝 ㅁ',
#  '이 머 전시 의 짝 퉁 게임 이 ㄴ가 발적 화 에 컨트롤 도 엄청 불편 하다 소방관 인공지능 이 너무 답답 하 다',
#  '푸르 ㄴ 바다 속 을 돌아다니 면서 작살 을 쏘 아 물고기 사냥 특별 하 ㄴ 사진 촬영 매장 되 ㄴ 보물 을 탐색 하 ㅂ니다 위의 행동 을 하 면 돈 획득 하 ㄹ 수 있 으며 좋 은 장비 를 구매 하 ㄹ 수 있 죠',
#  '게임 은 재밌 다 하지만 개발 사가 한글 패 하 지 오 통수 치고 결국 한글 패 하 지 무산 되 ㅁ',
#  '베데 스 다 넷 연동 하 었 는데 도 디 럭스 에 디 션 특전 안 뜨 는데 도 데 체 어떻 게 하 어야 뜨 는 거 이 ㅁ',
#  '졸라매 ㄴ 주제 에 타격 감 지리 네',
#  '재미있 기 는 한데 후반 에 갈수록 좀 지루 하 ㅁ 스토리 는 막장 의 재미 ㅎㅎ 깨 는데 시간 정도 걸리 는 것 같 은데 저 의 돈 주고 플레이 하 기 에 ㄴ 아까 움 세일 하 ㄹ 때 사 시 고 늘 ㄴ 덕 후 아니 면 필요 없 을 듯 함 나 는 안 사 었 음',
#  '뒤지 ㄴ 겜 업뎃하라고 하고 로 딩 걸리 고 계속 업 뎃 만 뜸 입구 컷 에 감동 받 아 비추 날 립 니 다',
#  '아직 미흡 하 ㄴ 점 이 많 지만 얼 리 억세스이기 도 하 고 많 은 발전 가능성 이 있 다고 봄',
#  '양민 학살 갓 갓 발암 게임 핵 유 저공 속 핵 사용자 보 았 음 도 있 는 갓 겜 임 초보 는 단지 무기 재조 재료 이 ㄹ 뿐 이 고 너무 많이 치 어 발리 어서 새소리 도 가꾸와가져와 로 들리 ㄹ 지경',
#  '데 누보 왜 안하 었 는지 모르 겠 음 업데이트 기다리 ㄴ 답 니 다 복 돌 님 듣 은 서 쭉 하 어 주 ㄹ 듯',
#  '초반 출시 단계 에서 는 퀘스트 무기 퀘 등 단순 반복 들 이 많 지만 업데이트 이후 수많 은 퀘들 이 생기 어 도전 과 수집 욕구 를 불러오 ㅁ',
#  '넘 모 심심 하 ㄴ 벨트 스크롤 겜 이 ㄴ 것 이 야요 뭐 가 있 다 싶 은 배경 에서 삽질하 다 보 면 아무 것 도 없 고 체력 만 줄줄 빠지 는 것 이 원 드 어 보일 키드를 사 다가 하 는 것 이 낫 지 싶 다',
#  '왜 스피드 가 고속 으로 하 지 않 았 는데 배 이상 빠르 게 느끼 어 짐',
#  '개인적 으로 게임 을 별로 좋아하 지 않 아서 거르 다가 사람 들 이 하도 갓 겜 갓 겜 거리 길래 세일 때 구매 하 어서 해보 았 는데 역시 낳 ㄴ 게임 을 좋아하 지 않 는다는 사실 을 한번 더 알 게 하 어 주 었 다 전투 가 너무 재미없 었 어',
#  '툼 레이더 리 부트 시리즈 를 모두 가지 고 있 어 구매 하 었 지만 이번 작품 은 스토리 볼륨 도 빈약 하 고 최적화 는 최적 화대 로 안되 어 있 고 이전 툼 레이더 시리즈 가 모험 과 전투 두 가지 를 다 잡 았 다면 이번 작품 은 두 가지 다 놓치 ㅁ 내가 이것 을 왜 사 었 지',
#  '게임 자체 는 좋 음 최적 화도 존 좋 습니다 게임 이 어렵 어요 정말 정말 어렵 어요 조작 을 베리 이지 로 하 어도 정말 정말 등 하 기 힘들 어요 개인적 으로 차 탓 이 라고 생각 은 하 ㄴ다만 마음 어렵 어 못하 겠 네 몸 으하하 핳 하하 하하 핳 크 라 이 써 ㅁ 모 얼',
#  '게임 은 재밌 는데 문제 는 사람 이 적 고 쏘 고 낳 ㄴ 후 몇 초 뒤 반동 이 나오 ㅁ',
#  '저희 집 이 쓰레기 같 은 컴 이 라 그렇 ㄴ지 아주 렉 이 심하 ㅂ니다 무료 되 서 가 아 지시 는 분 들 많 아서 저 도 가지 어 보 았 더니 아주 렉 이 심 하더군뇨 컴 이 아주 쓰렉 이 ㄴ 분 들 은 전 윈 비트 사용 하 지 않 는 것 을 추천 하 ㅂ니다',
#  '퍼즐 푸 는 중 이 ㄴ데 진짜 재밌 다',
#  '이거 일단 키 면 재밌 는데 키 기 가 싫 음 요새 한글 패 하 지 때문 에 레드 훅 말 이 좀 많 던데 추천 주 ㄹ지 비추 주 ㄹ지 고민 하 다가 그래서 비추 줌',
#  '오 아 조작 이 매우 어렵 습니다 사 아 양 은 의외로 고사 양 이 ㄴ 것 은 물론 이 고 롤러 코스터 에서 의 컨트롤 은 잊 으시 ㅂ시오 격자 가 없 는 엄청나 ㄴ 게임 이 ㅂ니다 마인 크래프트 처럼 격자 가 없 어서 매우 매우 건물 을 짓 기 힘들 ㅂ니다',
#  '미드 보다 게임 으로 먼저 접하 ㄴ 왕좌 의 게임 처음 에 는 정말 당황 하 었 다고 하 어야 하나 초반 에 화살표 나오 길래 겁 나 아 누르 었 는데 안되 고 마우스 도 안되 고 맞 나 계속 초반 에 죽 다가 키보드 눌르 어서 되 어 스 어 많이 당황 하 고 개 빡 친 역시 텔테일 이 ㅂ니다 나비 효과 짜 아 짱',
#  '한국 사람 이 ㄴ데 핑 이 적당 하 ㄴ 서버 가 하나 도 없 고 내가 서버 를 만들 ㄹ 수 도 없 어서 게임 을 재 대 로 하 ㄹ 수가 없 네요',
#  '이 새끼 들 보다 살 먹 고 휴대폰 에 또래 여자 번호 하나 없 는 내가 더 불상 하다 ㅣ 받',
#  '이 나 하자',
#  '주인공 이 급하 다고 대학원 생 연구 에 샘플 막 제 공해 서 영원히 고통 받 는 내용',
#  '이거 모바일 에 있 는 게임 을 그대로 옮기 ㄴ 게임 이 다 로 이식 하 ㄹ 때 에 는 인터페이스 라도 바꾸 는 것 이 맞 지 않 을까',
#  '이 야 멀티 나오 ㅁ',
#  '음 권장 사양 에 맞추 어 있 는데 프레임 이 떨어지 네요',
#  '하 면서 각종 파일 로 하면서 웃기 좋 은 게임',
#  '재밌 는데 오타쿠 들 왜 이리 불타오르 ㅁ 조작 감도 이정 도면 ㅍ ㅅ ㅌ ㅊ 아니 ㄴ가 따리 으 로 원활 하 게 잘 돌아가 는데',
#  '개인적 으로 ㄴ 과대평가 받 는 게임 이 라고 생각 하 ㅂ니다 처음 에 는 전투 시스템 이 참 괜찮 다 생각 하 었 는데 얼마 안 되 어 스 어 금방 지겹 어 지네 요 생각 을 돌이켜보 니 유저 를 사로잡 을 만하 ㄴ 새 롭 ㄴ 시스템 은 부족 하 고 여러 게임 의 요소 들 을 잘 융합 하 ㄴ 게임 이 ㄹ 뿐 이 라는 결론 을 내리 었 습니다',
#  '어디 서 는 가 아 받 은 무료 게임 생각 보다 괜찮 은데 돈 주 고 하 기 는 아깝 기 는 하다',
#  '게임 이 안 되 어 스 어 사놓 고 하 지 도 못하 ㅁ',
#  '유사 존 윅 게임',
#  '분 정도 하 었 다가 멀미 머리 아프 고 토하 ㄹ 정도 로 심하 어서 환불 하 ㅁ',
#  '그때 부터 이 었 어요 저 가 치 어 맞 고 다니 ㄴ 것 이 흙 흙',
#  '처음 튜 토리 얼 하 고 낳 ㄴ 느낌 은 롤 ㅋㅋㅋ 근데 재미 없습 롤 의 액션 성은 없으으면 서 롤 같 고 도타 의 타격 감 은 없 으면서 도타 같 음',
#  '좀비 가 너무 몰려오 ㅁ 그냥 디펜스 겜',
#  '배경 음악 덕분 에 엔딩 까지',
#  '으아 진짜 발적 화 진짜',
#  '게임 실행 이',
#  '노가다 성 이 너무 심하 어 재미 를 떨어뜨리 기 때문 에 비 추천 드리 ㅂ니다',
#  '캐릭터 가 잘생기 어서 물리 ㄹ 때 마다 넘나 리 슬프 어 ㅜ',
#  '팀 한번 밀리 면 아무것 도 못하 ㅁ',
#  '무엇 이 ㄴ지 잘 모르 겠 다 ㅇ',
#  '이 평가 에서 다루 는 대상 이 너무나 도 무섭 습니다 성 님 무섭 어서 아주 지려 버리 그 었 소',
#  '충 각 이 제일 강하 다',
#  '솔직히 서버 만 괜찮 으면 갓 겜 이 ㅁ',
#  '우 와 바 이브 컨트롤러 의 트리거 의 내구성 이 걱정 되 ㄹ 정도 로 정말 정신없이 플래이했습니 다 아직 캠페인 밖에 못 해보 았 지만 정말 꼭 해보 시 어야 하 ㅂ니다',
#  ...]

# %%
# tokenzier load

with open('tokenizer.p', 'rb') as file: # 파일을 바이너리 읽기 모드(rb)로 열기
    tokenizer = pickle.load(file)

# %%
test = list(map(str, test))

# 벡터화
test_data = tokenizer.texts_to_sequences(test)

# %%
max_len = 0
for i in test_data:
    if max_len <= len(i):
        max_len = len(i)
        
# 패딩을 통해 길이를 맞춰줍니다.
# from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.sequence import pad_sequences

test_data = pad_sequences(test_data, maxlen = max_len)

# %% [markdown]
# ### 모델 예측 // 21일, 주어진 데이터로 만들어놓은 모델을 사용해 예측해 줍니다.

# %%
y_pred = model__.predict_classes(test_data).reshape(-1)
# Out:
# WARNING:tensorflow:From <ipython-input-24-ed6c22034792>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
print(y_pred)
# Out:
# [1 0 0 ... 0 1 0]

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %% [markdown]
# ### 예측한 값을 엑셀 파일로 저장

# %%
import openpyxl

# %%
from openpyxl import Workbook

write = Workbook()
write_ = write.create_sheet("y값")

write_ = write.active

# 값 추가 / 행 단위
for i in y_pred:
    write_.append([i])
    
# 저장
write.save("예측한 값.xlsx")
